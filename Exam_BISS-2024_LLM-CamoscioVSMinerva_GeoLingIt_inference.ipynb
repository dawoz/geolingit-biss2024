# %% [markdown]
# <a href="https://colab.research.google.com/github/crux82/BISS-2024/blob/main/BISS-2024_LAB-2.3_ExtremITA_inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Camoscio VS Minerva LLMs comparison when finetuned on the GeoLingIt dataset

# %% [markdown]
# The tutorial is split into 4 steps, reflecting the aforementioned process:
# - Step 1 - Encoding the data
# - Step 2 - Training the LLaMA model
# - **Step 3 - Inference: generating answers**
# - Step 4 - Deconding the data

# %% [markdown]
# # Index:
# 1. Introduction, Workflow and Objectives
# 2. Preliminary steps
# 3. Loading the model
# 4. Generating answers
# 5. Saving the data in the 4-column format

# %%
# install eventually required packages

! pip3 install peft
! pip3 install sentencepiece
! pip3 install accelerate
! pip3 install bitsandbytes
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: peft in /home/dosclic/.local/lib/python3.9/site-packages (0.11.1)
# Requirement already satisfied: torch>=1.13.0 in /home/dosclic/.local/lib/python3.9/site-packages (from peft) (2.3.0)
# Requirement already satisfied: accelerate>=0.21.0 in /home/dosclic/.local/lib/python3.9/site-packages (from peft) (0.30.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib64/python3.9/site-packages (from peft) (1.26.4)
# Requirement already satisfied: safetensors in /home/dosclic/.local/lib/python3.9/site-packages (from peft) (0.4.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/site-packages (from peft) (23.2)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /home/dosclic/.local/lib/python3.9/site-packages (from peft) (0.23.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/site-packages (from peft) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib64/python3.9/site-packages (from peft) (5.9.8)
# Requirement already satisfied: transformers in /home/dosclic/.local/lib/python3.9/site-packages (from peft) (4.41.0)
# Requirement already satisfied: pyyaml in /usr/lib64/python3.9/site-packages (from peft) (5.4.1)
# Requirement already satisfied: filelock in /home/dosclic/.local/lib/python3.9/site-packages (from huggingface-hub>=0.17.0->peft) (3.14.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/site-packages (from huggingface-hub>=0.17.0->peft) (4.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (from huggingface-hub>=0.17.0->peft) (2.31.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/dosclic/.local/lib/python3.9/site-packages (from huggingface-hub>=0.17.0->peft) (2024.3.1)
# Requirement already satisfied: sympy in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (1.12)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (10.3.2.106)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (8.9.2.26)
# Requirement already satisfied: triton==2.3.0 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (2.3.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (3.1.3)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.0.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (11.4.5.107)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: networkx in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (3.2.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.13.0->peft) (2.20.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft) (12.2.140)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib64/python3.9/site-packages (from jinja2->torch>=1.13.0->peft) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib64/python3.9/site-packages (from requests->huggingface-hub>=0.17.0->peft) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3.9/site-packages (from requests->huggingface-hub>=0.17.0->peft) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests->huggingface-hub>=0.17.0->peft) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.9/site-packages (from requests->huggingface-hub>=0.17.0->peft) (2.10)
# Requirement already satisfied: mpmath>=0.19 in /home/dosclic/.local/lib/python3.9/site-packages (from sympy->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/dosclic/.local/lib/python3.9/site-packages (from transformers->peft) (0.19.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/dosclic/.local/lib/python3.9/site-packages (from transformers->peft) (2024.5.15)
# WARNING: Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
# distutils: /home/dosclic/.local/lib/python3.9/site-packages
# sysconfig: /home/dosclic/.local/lib64/python3.9/site-packages
# WARNING: Additional context:
# user = True
# home = None
# root = None
# prefix = None
# WARNING: You are using pip version 21.2.3; however, version 24.0 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sentencepiece in /home/dosclic/.local/lib/python3.9/site-packages (0.2.0)
# WARNING: Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
# distutils: /home/dosclic/.local/lib/python3.9/site-packages
# sysconfig: /home/dosclic/.local/lib64/python3.9/site-packages
# WARNING: Additional context:
# user = True
# home = None
# root = None
# prefix = None
# WARNING: You are using pip version 21.2.3; however, version 24.0 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: accelerate in /home/dosclic/.local/lib/python3.9/site-packages (0.30.1)
# Requirement already satisfied: huggingface-hub in /home/dosclic/.local/lib/python3.9/site-packages (from accelerate) (0.23.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib64/python3.9/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: psutil in /usr/local/lib64/python3.9/site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: safetensors>=0.3.1 in /home/dosclic/.local/lib/python3.9/site-packages (from accelerate) (0.4.3)
# Requirement already satisfied: torch>=1.10.0 in /home/dosclic/.local/lib/python3.9/site-packages (from accelerate) (2.3.0)
# Requirement already satisfied: pyyaml in /usr/lib64/python3.9/site-packages (from accelerate) (5.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/site-packages (from accelerate) (23.2)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: triton==2.3.0 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (2.3.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (4.10.0)
# Requirement already satisfied: sympy in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (2.20.5)
# Requirement already satisfied: fsspec in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (2024.3.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: networkx in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: filelock in /home/dosclic/.local/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (3.14.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.2.140)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.9/site-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib64/python3.9/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.9/site-packages (from requests->huggingface-hub->accelerate) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3.9/site-packages (from requests->huggingface-hub->accelerate) (1.26.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib64/python3.9/site-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /home/dosclic/.local/lib/python3.9/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# WARNING: Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
# distutils: /home/dosclic/.local/lib/python3.9/site-packages
# sysconfig: /home/dosclic/.local/lib64/python3.9/site-packages
# WARNING: Additional context:
# user = True
# home = None
# root = None
# prefix = None
# WARNING: You are using pip version 21.2.3; however, version 24.0 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bitsandbytes in /home/dosclic/.local/lib/python3.9/site-packages (0.43.1)
# Requirement already satisfied: numpy in /usr/local/lib64/python3.9/site-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: torch in /home/dosclic/.local/lib/python3.9/site-packages (from bitsandbytes) (2.3.0)
# Requirement already satisfied: filelock in /home/dosclic/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (3.14.0)
# Requirement already satisfied: sympy in /home/dosclic/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (1.12)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/dosclic/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.9/site-packages (from torch->bitsandbytes) (4.10.0)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/dosclic/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (8.9.2.26)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/dosclic/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (11.4.5.107)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/dosclic/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/dosclic/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (10.3.2.106)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/dosclic/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/dosclic/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (2.20.5)
# Requirement already satisfied: networkx in /home/dosclic/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (3.2.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/dosclic/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/dosclic/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/site-packages (from torch->bitsandbytes) (3.1.3)
# Requirement already satisfied: triton==2.3.0 in /home/dosclic/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (2.3.0)
# Requirement already satisfied: fsspec in /home/dosclic/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (2024.3.1)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/dosclic/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/dosclic/.local/lib/python3.9/site-packages (from torch->bitsandbytes) (11.0.2.54)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes) (12.2.140)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib64/python3.9/site-packages (from jinja2->torch->bitsandbytes) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/dosclic/.local/lib/python3.9/site-packages (from sympy->torch->bitsandbytes) (1.3.0)
# WARNING: Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
# distutils: /home/dosclic/.local/lib/python3.9/site-packages
# sysconfig: /home/dosclic/.local/lib64/python3.9/site-packages
# WARNING: Additional context:
# user = True
# home = None
# root = None
# prefix = None
# WARNING: You are using pip version 21.2.3; however, version 24.0 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import pandas as pd

from peft import PeftModel
from transformers import LlamaTokenizer, LlamaForCausalLM, GenerationConfig

# %% [markdown]
# ### Utils code for generating text in the ad hoc form for each task

# %%
def task_to_prompt(task: str):
    if task == "geolingit":
        return "Scrivi la regione di appartenenza di chi ha scritto questo testo, seguito dalla latitudine, seguita dalla longitudine."
    else:
        return "task sconosciuto"


 ################ GENERATE METHODS ################
def generate_prompt_pred(instruction, input_):
    return f"""Di seguito è riportata un'istruzione che descrive un task, insieme ad un input che fornisce un contesto più ampio. Scrivete una risposta che completi adeguatamente la richiesta.
### Istruzione:
{instruction}
### Input:
{input_}
### Risposta:"""

# %% [markdown]
# # Download the model
#
# This section provides detailed instructions on how to download and load the model. We specifically focus on the "Extremita" model, which has been trained and evaluated as part of a major competition. For more information on the competition and the model's performance, refer to the following link: https://ceur-ws.org/Vol-3473/paper13.pdf.
#
# The model is readily available on Hugging Face and consists of two main components: the original language model (Camoscio: ``sag-uniroma2/extremITA-Camoscio-7b``) and the adapters obtained through fine-tuning with all the data from Evalita 2023 in terms of adapters (``sag-uniroma2/extremITA-Camoscio-7b-adapters``).
#
# It is important to note that the model can be loaded using different precision levels, including 4-bit, 8-bit, and 16-bit approximations, as outlined below.

# %%
bits = "4" #@param [4, 8, "full"]

# %%
tokenizer = LlamaTokenizer.from_pretrained("yahma/llama-7b-hf")
tokenizer.padding_side = "left"
tokenizer.pad_token_id = (0)

# base model here, choose between 4, 8 bits or full precision
if bits == "8":
  model = LlamaForCausalLM.from_pretrained(
    "./LLaMinerva/checkpoint-426",
    load_in_8bit=True,
    torch_dtype=torch.float16,
    device_map="auto",
  )
elif bits == "4":
  model = LlamaForCausalLM.from_pretrained(
    "./LLaMinerva/checkpoint-426",
    load_in_4bit=True,
    torch_dtype=torch.float16,
    device_map="auto",
  )
else:
  model = LlamaForCausalLM.from_pretrained(
    "./LLaMinerva/checkpoint-426",
    torch_dtype=torch.float16,
    device_map="auto",
  )
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/39 [00:00<?, ?it/s]

# %%
model.config.pad_token_id = tokenizer.pad_token_id = 0
model.config.bos_token_id = tokenizer.bos_token_id = 1
model.config.eos_token_id = tokenizer.eos_token_id = 2

model.eval()
if torch.__version__ >= "2":
    model = torch.compile(model)

# %%
import pprint
import re

relPath = '.'
TASK = "geolingit"

inputs = []
with open(f"{relPath}/out/{TASK}/dev.txt", "r", encoding="utf-8") as f:
    for line in f.readlines():
        lc = re.split(r"\t|\[regione\]|\[geo\]", line)
        inputs.append(["1", TASK, lc[2], "[regione]" + lc[4] + " [geo]" + lc[5]])
    pprint.pp(inputs)
# Out:
# [['1',
#   'geolingit',
#   "[USER] Mortacci, na roba che nse po' vede, Por, na cacata rara.",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] In Liguria diciamo: CIU INLA’ U GHE CIOSU..!😂😂😂🤡🤡🤡',
#   '[regione] Liguria  [geo] 43.9 8.0\n'],
#  ['1',
#   'geolingit',
#   '[USER] Uuuuuuaaaaa.... [USER] si nu bell cafè cu nu bicchier d’ acqua '
#   'minerale ‘ngopp a na nave e crocier 🤣🤣🤣🤣🌹🌹🌹🌹',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Boffe a dui a dui finu caddivientanu rispari Pure così',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   '[USER] Anvedi andò stai. La prossima volta dimmelo pe tempo che te faccio '
#   'un saluto.',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'Sta Mejo lei che [USER] #nzonzi ma de che stamo a parlà [URL]',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] Certo che con questo approccio così "incisivo" cascheranno tutte ai '
#   "suoi piedi! (Detto siciliano un po' edulcorato: si l'avissiru a'mangiari i "
#   'canuzzi Nichi Nichi!) 🤮🤮🤮',
#   '[regione] Sicilia  [geo] 37.46 14.01\n'],
#  ['1',
#   'geolingit',
#   'Mia madre "Portate via na felpa che se fa freddo..." Io "Mama ghe xe 70 '
#   "gradi all'ombra e anche se fosse dove a impìroi che ea borsa xe drìo "
#   'sciopàre?" Le mie solite risposte pacate.',
#   '[regione] Veneto  [geo] 45.23 11.75\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] [USER] [USER] [USER] [USER] Poi se nn so più de tre '
#   'piotte nn vince....io gioco 3 euro pe vince 10 🤣🤣🤣🤣🤣',
#   '[regione] Lazio  [geo] 41.65 12.5\n'],
#  ['1',
#   'geolingit',
#   '[USER] Io voglio tornare allo Stadio... Accussi mi viru (forsi) u Catania '
#   '(sempre si ci campa) Semu n’de manu di nuddu...',
#   '[regione] Sicilia  [geo] 37.46 15.03\n'],
#  ['1',
#   'geolingit',
#   'Perchè dovete per forza "b-analizzare" un tweet...e sentiamo la sua di '
#   'soluzione quale sarebbe? Oi mà ma manciativi pani e ogghiju ccu ru zuccaru '
#   'che la vita è già pesante di suo😌 [URL]',
#   '[regione] Calabria  [geo] 39.1 17.1\n'],
#  ['1',
#   'geolingit',
#   'Ciao David salutame tu moje. Io vado dar fruttarolo [URL]',
#   '[regione] Lazio  [geo] 41.88 12.22\n'],
#  ['1',
#   'geolingit',
#   '[USER] Sveja alle 6:15 pe allacciasse le scarpe? Quanto cazzo so sexy! '
#   '👏👏👏👏👏💪🟡🔴❤️😘',
#   '[regione] Lazio  [geo] 42.44 12.06\n'],
#  ['1',
#   'geolingit',
#   '[USER] Una persona dall\'animo oscuro. Da noi si direbbe "ten la facc du '
#   'pept".',
#   '[regione] Puglia  [geo] 41.09 16.87\n'],
#  ['1',
#   'geolingit',
#   "[USER] L'ho visto soltanto adesso....grazie Per me oggi è così: Bacan d'a "
#   "corda Marsa d'aegua e de sa Che a ne Liga e a ne porta 'nte 'na creuza de "
#   'ma!',
#   '[regione] Liguria  [geo] 44.32 9.31\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] Certo giorge'...ce ne vuole di coraggio per riportare le "
#   "blaterazioni der capezza... Che te devi da inventa' pe cerca'de salva' la "
#   'tua poltrona...!',
#   '[regione] Lazio  [geo] 42.0 12.09\n'],
#  ['1',
#   'geolingit',
#   'Oü belin, ma mi avevano detto che non finiva così. Matteeeoooooooo !!!! '
#   '[URL]',
#   '[regione] Liguria  [geo] 44.44 8.88\n'],
#  ['1',
#   'geolingit',
#   "Amara cu non iavi a nuddu ..... Si io ho l'aiutante per finire i disegni "
#   '#cicciore #gatto artista #disegnomatita #disegno #paint #painting🎨 #gatti '
#   '#cat @ [LOCATION] [URL]',
#   '[regione] Sicilia  [geo] 38.17 15.53\n'],
#  ['1',
#   'geolingit',
#   'Vi atteggiate su instagram e Facebook e po si tutt muort e famm [URL]',
#   '[regione] Campania  [geo] 41.08 14.35\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ora che sta a casa da due anni, a capit ca nisciun o cac, '
#   "soprattutto all'estero, va benissimo tutto. Ciò che prima snobbava adesso "
#   "sono sfide, progetti intriganti. Ma per favore, lasciamolo dov'è questo "
#   'superbo arrogante ed antipatico. Non ci serve.',
#   '[regione] Campania  [geo] 40.81 14.06\n'],
#  ['1',
#   'geolingit',
#   '[USER] e er boja stava all’ordine der giorno. Adesso so’ antri tempi! Co’ '
#   'l’affare ch’er libbero pensiero sta a cavallo nessuno pô fa’ più quer che '
#   'je pare. In oggi, co’ lo spirito moderno, se a un Papa je criccasse '
#   'd’abbruciallo pijerebbe l’accordi cór Governo. Trilussa',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] Tu dici pensavo ca non capiva nenti nuddu🤦🏻\u200d♀️',
#   '[regione] Sicilia  [geo] 37.89 15.3\n'],
#  ['1',
#   'geolingit',
#   'Disca i n’aviva pil sutta l’ascell..! BUGIARDA! [USER] [USER]',
#   '[regione] Calabria  [geo] 39.1 17.1\n'],
#  ['1',
#   'geolingit',
#   'Quando è uscito 50 sfumature di grigio, tutte in calore a volersi fare '
#   'incatenare e bendare da Mr Grey. Ora pi na mascherina fannu nu burdellu chi '
#   'manchicani.',
#   '[regione] Calabria  [geo] 38.1 15.74\n'],
#  ['1',
#   'geolingit',
#   '[USER] A casa mia in dialetto si dice "Un manda ad Trump l\'è fin tropp"',
#   '[regione] Emilia Romagna  [geo] 44.9 11.12\n'],
#  ['1',
#   'geolingit',
#   '[USER] Allucinante intervento di Guido Bardi: epidemiologi e virologi '
#   'devono uscire di scena. È arrivato lui: tontu che sa nappa',
#   '[regione] Sardegna  [geo] 40.76 8.38\n'],
#  ['1',
#   'geolingit',
#   '[USER] Speruma ca vada bin',
#   '[regione] Piemonte  [geo] 44.98 7.62\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] Ma si .. frà na ' girata de sugo famo pure quarche pratica ! "
#   '😁',
#   '[regione] Lazio  [geo] 41.95 12.93\n'],
#  ['1',
#   'geolingit',
#   "[USER] A Barga ci abbiamo pranzato 🙈 E all'Isola Sacra ho immerso i piedi "
#   'nel torrente marmato!',
#   '[regione] Toscana  [geo] 43.5 11.55\n'],
#  ['1',
#   'geolingit',
#   "Se t'ha furia t'avevi a sveglià prima",
#   '[regione] Toscana  [geo] 43.73 11.15\n'],
#  ['1',
#   'geolingit',
#   '[USER] ..ehh mannaggia mannaggia devi esse bello sfigato pe’ avecce i soldi '
#   'nei momenti sbajati',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ita diaulu mi è mancata acqua sotto la doccia 🚿',
#   '[regione] Sardegna  [geo] 40.76 8.38\n'],
#  ['1',
#   'geolingit',
#   'Si vede ca tenit a cap sul pe sparter e’recchie😩 [URL]',
#   '[regione] Puglia  [geo] 40.04 18.01\n'],
#  ['1',
#   'geolingit',
#   'Ad occhio è come i mercati di suning Nel suo prime curpa del settlement Poi '
#   'ci fu il rispetto dell ffp Nel middle age la colpa fu del governo Nei '
#   'giorni nostri la pandemia A ghe sempar quel, l è mai cota [URL]',
#   '[regione] Lombardia  [geo] 45.0 10.73\n'],
#  ['1',
#   'geolingit',
#   '▪️Presentazion de gnove stagjon teatrâl dal Teatri Stabil Furlan, une vore '
#   'siore di colegaments e di ativitâts. ▪️Presentazione della nuova stagione '
#   'teatrale del TeatroStabileFriulano, molto ricca di collegamenti e di '
#   'attività. [USER] [USER] [USER] [USER] [URL]',
#   '[regione] Friuli-Venezia Giulia  [geo] 46.05 13.23\n'],
#  ['1',
#   'geolingit',
#   '[USER] Salvììì fall pa Maronn, stat a cas',
#   '[regione] Campania  [geo] 40.65 14.45\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] chidda è a me barca',
#   '[regione] Calabria  [geo] 38.01 15.83\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] In foto da solo nel tramonto 😂😂😂😂 n’cha n’amica n’anima pia '
#   'qualcuno che gli dia na mano insomma😂😂😂😂😂',
#   '[regione] Lazio  [geo] 41.79 12.61\n'],
#  ['1',
#   'geolingit',
#   '[USER] Sisì, ma alzalo il riscaldamento, porcu diau!',
#   '[regione] Liguria  [geo] 44.44 8.88\n'],
#  ['1',
#   'geolingit',
#   '[USER] si pur orgoglios e metter stu video? I me mettess scuorn',
#   '[regione] Campania  [geo] 40.93 14.25\n'],
#  ['1',
#   'geolingit',
#   '[USER] Nuie simm semp esagerati',
#   '[regione] Campania  [geo] 40.9 14.48\n'],
#  ['1',
#   'geolingit',
#   "Sarò l'unico che abita al mare e che nu je va de anna' ar mare...😝🙈",
#   '[regione] Lazio  [geo] 41.49 12.59\n'],
#  ['1',
#   'geolingit',
#   'Mi ha contattato un coppia che mi chiede se posso far parte a dei loro '
#   'giochi... Mannagg ca stann luntan, na passat a Monopoli ma fa facev 😅',
#   '[regione] Campania  [geo] 40.83 14.33\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] ...dat foc rumbabit (datti fuoco rimbambito)',
#   '[regione] Toscana  [geo] 44.07 10.09\n'],
#  ['1',
#   'geolingit',
#   '[USER] Te gh’è minga ii cufi de ratt muschiè? 🤔',
#   '[regione] Lombardia  [geo] 45.46 9.15\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ghe silenzi in casa… dormen tuti..mi no.. voria dir prima dormi ben '
#   'anca ti Sergio .. po dormirò anca mi.sss… ⭐️⭐️⭐️ [URL]',
#   '[regione] Veneto  [geo] 45.62 10.68\n'],
#  ['1',
#   'geolingit',
#   "Lettera di Verdini a Dell'Utri e Confalonieri x la migliore strategia al "
#   "fine di eleggere il Kaimano Che bella comitiva di uomini d'onore a "
#   "rappresentare l'Italia Nuddu si pigghia s'un s'assumighia Non c'è + non "
#   'dico dignità ma semplicemente senso della misura😊 MALEDETTI',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   "[USER] Maro' Napolista ma scrivss na vota coccos e bbuon!🤦",
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[URL] ma che cazzo jà tirato? no staccio bagnato. io je tiravo na castagna '
#   'che rimaneva così come sta',
#   '[regione] Lazio  [geo] 41.88 12.22\n'],
#  ['1',
#   'geolingit',
#   'Vabbè s’impegnato, ma na mezzorata pe stasamme er buco de sto cesso la poi '
#   'trova’?!?! [URL]',
#   '[regione] Toscana  [geo] 43.89 10.78\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] Boia, ma per bé un coctel così, un basta 'na 'annuccia, ci "
#   "vole 'na grondaia...",
#   '[regione] Toscana  [geo] 43.66 10.36\n'],
#  ['1',
#   'geolingit',
#   "[USER] E se la pija 'nder culo? Sì",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'Da leggere velocemente!.. Buon divertimento 😉😄 Chistu è difficile!.. [URL]',
#   '[regione] Sicilia  [geo] 38.16 13.23\n'],
#  ['1',
#   'geolingit',
#   'Ancor c’amma assettà a tavol e già me gir a cap… 😵\u200d💫 Jamm bell Buon '
#   'anno 🥂',
#   '[regione] Campania  [geo] 40.03 15.37\n'],
#  ['1',
#   'geolingit',
#   '[USER] Tuttu stu mistero x nu scatulu di fru fru 😅😅',
#   '[regione] Calabria  [geo] 39.27 16.27\n'],
#  ['1',
#   'geolingit',
#   'non son scovazzini, se meti li col telefonin e non pulissi. xe sporco de '
#   'tre anni fa questo [risvegli] [URL]',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.67 13.78\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] Vabbè ma mi fratello è un greve, du metri de omo, te '
#   'da na pizza, te ribalta, campione del mondo de rutti, mica mignolino '
#   'alzato.',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] Chi ha i denti unn’ha i pane e chi ha i pane unn’ha i denti 😂😂',
#   '[regione] Toscana  [geo] 43.78 11.24\n'],
#  ['1',
#   'geolingit',
#   "[USER] Ti ammiro, sei un esempio! Io vago in semi-libertà😂 nun m'aggjo "
#   'ancora capit bbuon😊',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] Me meto i anfibi',
#   '[regione] Veneto  [geo] 45.4 12.38\n'],
#  ['1',
#   'geolingit',
#   "[USER] Mo socci, che fadiga! 🙄 mi dispiace. 💞 tin bota, va' là",
#   '[regione] Emilia Romagna  [geo] 44.48 11.33\n'],
#  ['1',
#   'geolingit',
#   '[USER] Incraradi ca iese sa serra tottu niada! Tittia, su frittu ❄',
#   '[regione] Sardegna  [geo] 40.01 9.25\n'],
#  ['1',
#   'geolingit',
#   'Scusa Giucas, ma in italiano non si può sentire. "L\'acqua ni vagna e u '
#   'viantu n\'asciuca". E non è tua. #gfvip',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   'La Casellati che sosteneva una zo...la per nipote di Mubarak, da PdR '
#   "potrebbe “scagnà o' cazz' p'a banca e' ll'acqua”",
#   '[regione] Campania  [geo] 40.7 14.47\n'],
#  ['1',
#   'geolingit',
#   '[USER] Era mejo quanno la vita era circoscritta ar proprio quartiere e '
#   'sapevamo solo i cacchi der palazzo.',
#   '[regione] Lazio  [geo] 42.21 12.42\n'],
#  ['1',
#   'geolingit',
#   '[USER] Nte sei perso ncazzo dammi retta',
#   '[regione] Lazio  [geo] 41.49 12.59\n'],
#  ['1',
#   'geolingit',
#   "Tanto da tifare #Belgio contro l'#italia agli #Europei??? Maial ac "
#   'paiaz....🤡🤡🤡🤡 [URL]',
#   '[regione] Emilia Romagna  [geo] 44.8 11.67\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] Che casso set a Dre a dì Teo?? L'ho messo nel Google "
#   'translate, ma sé smursat...',
#   '[regione] Lombardia  [geo] 45.29 9.84\n'],
#  ['1',
#   'geolingit',
#   '[USER] Beh...mors tua vita mea ... Che ragionamenti del belino',
#   '[regione] Liguria  [geo] 44.38 9.15\n'],
#  ['1',
#   'geolingit',
#   '#staseraitalia Oh, ma se Corradino non dice "Salvini" almeno tre volte in '
#   'una frase non è contento. Lo cita anche alla belin di cane, quando non '
#   "c'entra una emerita. Alla faccia della fissazione!",
#   '[regione] Liguria  [geo] 44.01 8.16\n'],
#  ['1',
#   'geolingit',
#   '[USER] Come si dice...ah sì "a megghio parola è chidda ca un si rice" 😂😂😂😂',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] È bastata na sciura all’autogrill per far cadere il velo di '
#   'ipocrisia nel quale si è bardato... #Ranucci',
#   '[regione] Lombardia  [geo] 45.46 9.15\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Per inciso, state facendo il suo gioco...[USER] è nu figl i '
#   "bucchin...ed è proprio a questo che ambisce...come si dice...v sta' "
#   'strunziann 😜',
#   '[regione] Campania  [geo] 40.79 14.43\n'],
#  ['1',
#   'geolingit',
#   'Sit a sfaccimm e tutt e squadre..munnezz [URL]',
#   '[regione] Campania  [geo] 41.19 14.84\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] [USER] [USER] A +de qualchidun ghe faria solo che ben',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.59 13.77\n'],
#  ['1',
#   'geolingit',
#   '[USER] 😂😂😂😂😂 è sicur ! L’ev pensat pur’j 😂😂😂😂 ma pure gli arbitri sono '
#   'asimmetrici? Tenen’e corn’sotto',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] Di sti tempi non le miga na brutta roba... mei chi che alla villetta '
#   '😂',
#   '[regione] Emilia Romagna  [geo] 44.78 10.32\n'],
#  ['1',
#   'geolingit',
#   "[USER] Ergo: 🗣famose paga' che' stamo adda' lezioni ar mondo🥵ed e' "
#   'fatica🥵🥵‼️🤣🤣🤣🤣🤣🤣🤣',
#   '[regione] Lazio  [geo] 41.47 12.69\n'],
#  ['1',
#   'geolingit',
#   "E facit'o cess' tutt' quant'! ✊💯☠️💯 [URL]",
#   '[regione] Campania  [geo] 40.9 14.3\n'],
#  ['1',
#   'geolingit',
#   'Cossa varditu? @ [LOCATION] [URL]',
#   '[regione] Friuli-Venezia Giulia  [geo] 46.0 12.6\n'],
#  ['1',
#   'geolingit',
#   "Possibile l'unía che m'ha messo mi garbi su Dating, fa voglia di caá...😰😭",
#   '[regione] Toscana  [geo] 43.66 10.36\n'],
#  ['1',
#   'geolingit',
#   'Chist ten 60 anni, ma è cchiu muccus delle mie figlie [USER] tu che spesso '
#   "ci dialoghi, mi fai il piacere di dire, che a fa l'omm non è difficile. "
#   'Altro tifoso della SSCAURELIO, guai a parlargliene MALE RIDICOLO [URL]',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   'Chi volit da me Sugnu ca e nun sacciu nent #chilhavisto',
#   '[regione] Calabria  [geo] 39.1 17.1\n'],
#  ['1',
#   'geolingit',
#   'Il mare difende idda, ‘a Muntagna. [USER] [URL]',
#   '[regione] Sicilia  [geo] 37.84 15.26\n'],
#  ['1',
#   'geolingit',
#   'Oh! Boia fauss! Fate i buoni e mettete la mascherina [URL]',
#   '[regione] Piemonte  [geo] 44.3 7.61\n'],
#  ['1',
#   'geolingit',
#   'Figa il Pub sotto casa fa serata (con rispetto distanze e tutto ok lo '
#   'scrivo subito) ma il problema mica è quello è che volevo sedermi al bancone '
#   'senza tanti cazzi farmi 3 Medie e tornare a casa e crollare. Invece quelli '
#   'fanno Pe Pe Pe Pe.',
#   '[regione] Lombardia  [geo] 45.46 9.15\n'],
#  ['1',
#   'geolingit',
#   "[USER] Sapevano una sega di 'ome si fa 'na fiorentina...",
#   '[regione] Toscana  [geo] 43.66 10.36\n'],
#  ['1',
#   'geolingit',
#   '[USER] Buongiorno, oggi riparto e ritorno nella nebbia, ahimè. Già m manc '
#   "l'addor ro cafè. Terra Mia 💙",
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ghe sarà galimba cul mantel de superman che el vula in gir a fa i '
#   'cuntroi!!!!',
#   '[regione] Lombardia  [geo] 45.13 10.02\n'],
#  ['1',
#   'geolingit',
#   '[USER] minchia....davvero ...ma proprio tutto tutto ? va cagher cuion !',
#   '[regione] Piemonte  [geo] 44.91 8.2\n'],
#  ['1',
#   'geolingit',
#   '[USER] E allura semu a cavaddu...🤣🤣🤣🤣',
#   '[regione] Sicilia  [geo] 37.46 15.03\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ah, beh.. qui è "gocc a davè! (Devi avere una goccia, ovvero un '
#   'malore, un guaio, ecc) lo usiamo anche se ci fanno spaventare: gocc a davè, '
#   'mi si fatt piggjià na gocc!',
#   '[regione] Puglia  [geo] 41.09 16.87\n'],
#  ['1',
#   'geolingit',
#   "[USER] Belin ma il presidente di Federalberghi era d'accordo con tutte le "
#   'belinate che propinava Draghi ora ad albergo vuoto si sveglia? Dimissioni '
#   'subito se non è in grado di capire cosa serve al suo settore.',
#   '[regione] Liguria  [geo] 44.44 8.88\n'],
#  ['1',
#   'geolingit',
#   'Tant a lor no i cambie nie. Ridicui. [URL]',
#   '[regione] Friuli-Venezia Giulia  [geo] 46.05 13.23\n'],
#  ['1',
#   'geolingit',
#   'Rendiamoci conto:Per queste porcherie, prima o poi, i comunisti dovranno '
#   'pagare...non nascondere la "rumenta" sotto il tappeto. [URL]',
#   '[regione] Liguria  [geo] 43.9 8.0\n'],
#  ['1',
#   'geolingit',
#   'E che li deve sparare in mezzo al mare ? Sient a mme , vivi e lascia vivere '
#   '. [URL]',
#   '[regione] Campania  [geo] 41.4 13.97\n'],
#  ['1',
#   'geolingit',
#   'Veh’ che amici fichi che ho. [URL]',
#   '[regione] Emilia Romagna  [geo] 44.48 11.33\n'],
#  ['1',
#   'geolingit',
#   'Ciao [USER] quanno je date na bella sveja a quelle che tanto vanno in giro '
#   'ad atteggiarsi?? Fateme sapè',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'Ultime pirlate del pupazzo di Grillo ( di Mario) rilascia intervista a '
#   'tutto spiano,il PEGGIO del movimento è sempre in prima linea.... Prima che '
#   'sto cagone ci porta a livello di Italia Morta va cacciato a pedate il '
#   'TRADiTORE Di Maio.',
#   '[regione] Lombardia  [geo] 45.48 9.65\n'],
#  ['1',
#   'geolingit',
#   'E magari, esclusa costei (che sa benissimo di scrivere una virgolata '
#   'diaulu), qualcuno ci crede... Millantare millantare fortissimamente '
#   'millantare [URL]',
#   '[regione] Sardegna  [geo] 40.76 8.38\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Pani e casu e binu a rasu!',
#   '[regione] Sardegna  [geo] 39.22 9.09\n'],
#  ['1',
#   'geolingit',
#   "[USER] La pandemia che non si placa o napule ca c'accis mo pure Draghi cu "
#   "Brunetta Germini e Carfagna cavvimm passa' cchiu'!? 🤦🤦🤦🤦🙄🙄🙄🙄",
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   "[USER] Ma nce potemo mette er tutor tattico a fa' r'sindaco?",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'questo mi ha attaccato na pezza su quanto alcune persone con un livello di '
#   'istruzione basso siano molto più intelligenti di gente laureata ecc ma io '
#   'ho soltanto condiviso il video della mia vrenzola prefe che fa gli auguri '
#   'di Natale non capisco come facciate a essere sempre così',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] E no ciò, ghi no visti sia a Rosà che verso Sitadea... '
#   'e non xè città',
#   '[regione] Veneto  [geo] 45.68 11.74\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Non trovo differenze tra te e quello del video, uno è na '
#   'latrin napoletana tu na lot bresciana.Che sia del nord o del sud, sempre di '
#   'cess parliamo',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] Che te devo di’ ... stai ‘na crema 🤪😂😉 peccato tu non sia vicina, '
#   'altrimenti ... te farei ‘na corte spietata 😂🤣😂 sei fantastica Nina‼️🤗💋😘',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'Me stavo pe innamorà del Signor Toro (nomen Omen?) che suonava la tuba '
#   "sull'atac ma poi ha detto a Papà Pig che è grasso e ce so rimasta na cifra "
#   'male. [URL]',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'Sono triste a casa con la moglie che mi vuole tutto per lei.. al momento mi '
#   'salva #techetechete... rai 1 trop bel..',
#   '[regione] Emilia Romagna  [geo] 44.8 10.6\n'],
#  ['1',
#   'geolingit',
#   "Nebbia ghe n'è? [URL]",
#   '[regione] Veneto  [geo] 45.36 11.04\n'],
#  ['1',
#   'geolingit',
#   "Oh raga, se volete, 'nvece di mandá figlioli a scuola a pigliá 'r corona, "
#   'io e [USER] si dà lezioni su parole sdrucciole, punti e virgole e accenti '
#   "'e cascano....",
#   '[regione] Toscana  [geo] 43.66 10.36\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Allora ...visto che io sono il migliore del creato ...ti '
#   "risponderò ...si è vero ma c'è anche la iperadulazione !!! 🤣🤣🤣 Buongiorno "
#   "Bea tosa steto ben ? Cossa feto 'sto sábado e domenega ? Viento a Venexia ? "
#   'Te speto ?',
#   '[regione] Veneto  [geo] 45.45 11.74\n'],
#  ['1',
#   'geolingit',
#   "Pe sta' cena de sabato già me so partite du piotte...",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] Picchi su belli.... Avanti chi ci vulissi riri a da carusa...',
#   '[regione] Sicilia  [geo] 37.46 15.03\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] Te da 'na zinnata, t' aresteno pe vagabondaggio...",
#   '[regione] Lazio  [geo] 41.76 12.63\n'],
#  ['1',
#   'geolingit',
#   'A rotto il cazzo smalling prendetelo sto centrale che questo e fracico piu '
#   'de na mozzarella x dio',
#   '[regione] Lazio  [geo] 41.25 13.08\n'],
#  ['1',
#   'geolingit',
#   'Na roba che me mette na cifra in difficoltà è riceve le foto delle '
#   'ecografie dei pupi nella pancia. Non so mai che dire. Che devo dì? "Che '
#   'bello?" Cioè, io vedo na cifra de macchie nere e bianche e non ce capisco '
#   'nulla, e manco me piace Pollock, che ce trovate di meraviglioso?',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Ehm pe na volta se vede qualcosa che realmente c’è. 😅',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] ..ahhh, ma allora un te la pigliá, meglio arzilli che mosci...😉',
#   '[regione] Toscana  [geo] 43.66 10.36\n'],
#  ['1',
#   'geolingit',
#   "Oh Boris #Johnson , ma fatti 'apelli...😤😤",
#   '[regione] Toscana  [geo] 43.66 10.36\n'],
#  ['1',
#   'geolingit',
#   'Se il governatore della Toscana chiude l’empolese dee anda a stroncasselo '
#   'ni culo lui e qui’ troiaio dell’unione dei comuni, m’importa una sega io do '
#   'di barta se mi richiudono',
#   '[regione] Toscana  [geo] 43.75 10.99\n'],
#  ['1',
#   'geolingit',
#   "[USER] Ma nu ghe' SEMMU ☹️☹️☹️",
#   '[regione] Liguria  [geo] 44.44 8.88\n'],
#  ['1',
#   'geolingit',
#   'Itte mi nda futti der sa cazzadasa de tottusu. Marrattilu tue. Ia isco sas '
#   "cazzadas tua. Bi, mi che lar tirar dae inoche e mi l'acches paccare e meda "
#   "puru. Itte ba, abba es colande? No no mi, s'interesse meu sun propriu sas "
#   'mestruaziones tua. [URL]',
#   '[regione] Sardegna  [geo] 40.33 9.3\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Sient nui amm vinciut 2 scudetti e qualche coppa...chist è o '
#   'fatt e 3 cose buone ho fatto, perche mi volete togliere pure quelle... 😂 😂 '
#   '😂',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ammazza però nte se po chiede gnente! 😉',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "2.6.2022 Italia-Argentina 0-3 L'italian la ciapà tri sgiafuni da "
#   "l'argentin. Sperem che cuntinuen a giüga insema ne l'#Inter 🤔 (for who were "
#   "born below the Po river: l'italiano ha preso tre sberloni dall'argentino. "
#   "Speriamo continuino a giocare insieme nell'#Inter) 🙏 [URL]",
#   '[regione] Lombardia  [geo] 45.44 9.02\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Mi a luglio😬 però gera destin perché aea fine se gavemo '
#   'conossùo da grandi 😉',
#   '[regione] Veneto  [geo] 45.4 12.38\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Ma vogliamo parlare della voce di Carmen Consoli??? Maial '
#   'quanto mi disturba...',
#   '[regione] Emilia Romagna  [geo] 44.8 11.67\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] Devono rimanere sommersi dalla loro stessa Rumenta '
#   '🤦\u200d♂️',
#   '[regione] Liguria  [geo] 44.44 8.88\n'],
#  ['1',
#   'geolingit',
#   '[USER] Mio suocero va oltre: “ma pi ‘dla not” ( solo più della notte”',
#   '[regione] Piemonte  [geo] 44.53 7.96\n'],
#  ['1',
#   'geolingit',
#   '[USER] avoja a piedi proprio così manco penamo pe parcheggià',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Ma te non c’hai de mejo da fa che rompe i coioni ? È un '
#   'problema tuo se lei vuole fa sta domanda!? Ma vatte a fa un giro invece de '
#   'da lezioni de vita.',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "[USER] Lh'o sapessimo, che lh'o sappiamo lh'o sapremmo che tutti lh'o "
#   'sanno? LU sapimo LU sapimo puru nui tranquilli. #RIDICOLI. 🇮🇹🇮🇹🇮🇹SEMPRE.',
#   '[regione] Puglia  [geo] 39.88 18.24\n'],
#  ['1',
#   'geolingit',
#   "#QuartoGrado pe niente fastidiosa la voce de st'inviata",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'Bon gavemo capì, sei donna, MOEGHEA!! #BallandoConLeStelle',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.67 13.78\n'],
#  ['1',
#   'geolingit',
#   '[USER] Melí puzzi viva, arricettati anna rasa x piacere e chiuda sta vucca',
#   '[regione] Calabria  [geo] 39.27 16.27\n'],
#  ['1',
#   'geolingit',
#   '[USER] In dialetto, piciu, aso, delinquent.',
#   '[regione] Piemonte  [geo] 45.45 7.73\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Allora dovevi rispondere:"Cchi\'camurria...."🤣',
#   '[regione] Sicilia  [geo] 37.46 14.01\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Quandu li zzicca su cazzi loru!',
#   '[regione] Puglia  [geo] 40.19 18.14\n'],
#  ['1',
#   'geolingit',
#   'Io che mi rilasso a casa al mare E "minni fricu"😌 [URL]',
#   '[regione] Calabria  [geo] 38.95 17.07\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] Eh appunto, t'ho nel cuore ma ti vo nel...",
#   '[regione] Toscana  [geo] 44.06 10.37\n'],
#  ['1',
#   'geolingit',
#   '[USER] Emmo, duoso istididoso de abba e non piganta prusu is telefonoso. '
#   'Ispereusu poderede',
#   '[regione] Sardegna  [geo] 40.01 9.25\n'],
#  ['1',
#   'geolingit',
#   "[USER] A me pare un'altro babaciu yoda stile.",
#   '[regione] Piemonte  [geo] 44.57 8.32\n'],
#  ['1',
#   'geolingit',
#   "Oi Stefà nuij subba 'a Salerno-Reggio Calabria usamu 'u ciucciu ccu 'i "
#   "cavaddri a trainu e 'a spisa d'arretu [URL]",
#   '[regione] Calabria  [geo] 38.95 17.07\n'],
#  ['1',
#   'geolingit',
#   '[USER] Vai Marta! Altro che Cortina! Füma ‘l mundial a Demönt. 😂 In bocca '
#   'al lupo per tutto!',
#   '[regione] Piemonte  [geo] 44.41 7.55\n'],
#  ['1',
#   'geolingit',
#   '[USER] Daiii ma fatt e fatt tuoje 😂',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] Te ga volù la moie giovine, desso te speti...',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.61 13.86\n'],
#  ['1',
#   'geolingit',
#   "[USER] Su Cugghijuni. Il cannolo sulu a na manera ha d'essari mangiato.",
#   '[regione] Calabria  [geo] 38.67 16.09\n'],
#  ['1',
#   'geolingit',
#   "#CalendaSindaco ? Erano meglio Buzzi e Carminati. Chist... ten 'a facc... è "
#   'ebet... [URL]',
#   '[regione] Campania  [geo] 40.94 14.63\n'],
#  ['1',
#   'geolingit',
#   '[USER] Qualcuno si stupisce? È la paghetta dei bon da gniint, i mafiosi '
#   'sono bon da gniint level pro. O no?',
#   '[regione] Emilia Romagna  [geo] 44.69 10.63\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] Va beh, ghe digo che a ghe meta a crema, poro ceo',
#   '[regione] Veneto  [geo] 45.4 12.38\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] MA se li hai chiusi tu..di quale merito parli? STATT A CAS.',
#   '[regione] Campania  [geo] 40.9 14.3\n'],
#  ['1',
#   'geolingit',
#   'Live #Giro2022 elicottero sopra casa mia, sopra la città, sento il rumore e '
#   'la vedo in tv. Soccia slè bèla Bulàgna ❤️',
#   '[regione] Emilia Romagna  [geo] 44.48 11.33\n'],
#  ['1',
#   'geolingit',
#   '[USER] Buongiorno, oggi chiov’ tutt a jurnat’, c’è serv’ o mbrell’.',
#   '[regione] Campania  [geo] 40.92 14.12\n'],
#  ['1',
#   'geolingit',
#   'Non è mai tardi però per NON dire cavolate...lasuma perdi ca le mei! [URL]',
#   '[regione] Piemonte  [geo] 45.05 7.59\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ma nun è da retta, nun stann bon ca capa.... Il problema non sei tu '
#   'ma loro. Stai benissimo!! 😉🙂',
#   '[regione] Toscana  [geo] 44.02 11.32\n'],
#  ['1',
#   'geolingit',
#   '[USER] Vabbe allora dime che sò sfigà...',
#   '[regione] Veneto  [geo] 45.54 11.55\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] O i famosi mandilli au pestu. Poi se vuoi stravincere ti '
#   'giochi a levre di cuppi (cit creusa de ma) ed è fatta ;)',
#   '[regione] Liguria  [geo] 43.86 7.93\n'],
#  ['1',
#   'geolingit',
#   "[USER] Curri quantu vuoi ca cà t'aspjettu",
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   '[USER] Vien a te fa na camminata, puo essere che diventi un poc omm..',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] Te sa si... Ierimo in scooter mi è mia fia e no iera facile.',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.77 13.51\n'],
#  ['1',
#   'geolingit',
#   "[USER] Taca a guardar a cà da ti cl'è ora, purtinar!!!!",
#   '[regione] Emilia Romagna  [geo] 44.8 11.67\n'],
#  ['1',
#   'geolingit',
#   'MA IO SAREI SALITA SUBITO SUL TRENO CHE SCHERZI AMOOOO TUTT STU BURDELL '
#   '#harrypotter',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] e allora niente Eduardo... ...ci tnimm tutt chell che è nuost!',
#   '[regione] Campania  [geo] 40.84 14.1\n'],
#  ['1',
#   'geolingit',
#   '[USER] Fuori casa mia anche di più stae nu mare e nu ientu ca te nde '
#   'portane😁',
#   '[regione] Puglia  [geo] 40.04 18.01\n'],
#  ['1',
#   'geolingit',
#   '... oh Signur di puarit,quel di sciuri el g’ha i curnit,quel di fraa l’è '
#   'scapàa, quel di munèch l’è disperàa. ....per trend a breve termine non '
#   'significa secondi o minuti o ore,sifnifica qualche giorno÷fino a un paio di '
#   'settimane al massimo',
#   '[regione] Lombardia  [geo] 45.46 9.15\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ma vir nu poc è c s pass Mo abbiamo girato la frittata È la sua cosa '
#   'perche poi piacciono pure altri, ma magari fosse questo 😂',
#   '[regione] Campania  [geo] 40.92 14.12\n'],
#  ['1',
#   'geolingit',
#   "[USER] Mettece n'artro filtro nella foto a ridicola 😂😂",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'Se non ti mette al primo posto...deve andare in mona!',
#   '[regione] Friuli-Venezia Giulia  [geo] 46.1 12.87\n'],
#  ['1',
#   'geolingit',
#   '[USER] Stea mia, el governo rosso verde ga fato soło na roba: emergensa '
#   'covid. Te ricordito altro? E che ghe piaxa o no el bauco de Speransa, che i '
#   'gaveva meso la pensando no contasse (senza portafoglio), xe sta el ministro '
#   'più importante',
#   '[regione] Veneto  [geo] 45.4 12.17\n'],
#  ['1',
#   'geolingit',
#   'Coso è tornato a lavoro, e mentre giro pe casa in bigodini e mise che fa '
#   'invidia a na balena vestita ballerina del Moulin Rouge, suona il più gran '
#   'pezzo de fico della storia e me dice che deve staccà la luce e io faccio '
#   'capolino coi bigodini e la vestaglia de chiffon. Tacci mia.',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] Vecio ricordate che oltre al magnar bisogna anca bever! '
#   '#marcozennaroliberosubito [URL]',
#   '[regione] Veneto  [geo] 46.26 12.26\n'],
#  ['1',
#   'geolingit',
#   'Ma Ramazzotti vando dice "sono ancora impantanato con te", o dov\'è andato '
#   'a trombá, nella mota..?',
#   '[regione] Toscana  [geo] 43.66 10.36\n'],
#  ['1',
#   'geolingit',
#   'Se tutto va per il verso giusto (è fazzu corna 🤘 tuccannu ferro) tu non ti '
#   'devi avvicinare al Cibali neanche in prossimità del 300km di perimetro. '
#   '[URL]',
#   '[regione] Sicilia  [geo] 37.46 15.03\n'],
#  ['1',
#   'geolingit',
#   '[USER] u capivu, mi va fazzu a doccia 😂😂😂',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   '[USER] Se volete vi svelo il segreto. Però domani lo mettete in prima '
#   'pagina. "An n\'è menga tant biand" (non è tanto biondo) vuol dire che non '
#   'si è propensi a farsi fregare.',
#   '[regione] Emilia Romagna  [geo] 44.58 10.85\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] [USER] [USER] [USER] [USER] Mi meraviglio di [USER], '
#   'che risponde a questa gentaglia. Il signore simone continua a fare o gall '
#   "n'cop a munnezz...",
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '"Post mortem nihil est ipsaque mors nihil, velocis spatii meta novissima" '
#   "... che vor dì dopo la morte non esiste più nulla e ce ne s'ha per 3 caate",
#   '[regione] Toscana  [geo] 42.85 11.48\n'],
#  ['1',
#   'geolingit',
#   'Sul figur d merd... Si stanno arrampicando ovunque ci si possa arrampicare '
#   '🤣🤣🤣🤣 [URL]',
#   '[regione] Campania  [geo] 41.1 13.91\n'],
#  ['1',
#   'geolingit',
#   "[USER] boja fauss! per na volta che l'huma cumbina'... 😡",
#   '[regione] Piemonte  [geo] 45.07 7.67\n'],
#  ['1',
#   'geolingit',
#   "[USER] Gheto mai senti' parlar de la politica?",
#   '[regione] Veneto  [geo] 45.23 11.75\n'],
#  ['1',
#   'geolingit',
#   'Buon campionato butei...e forsa Verona e kumbulla va in mona ti e tutti '
#   'quei che hanno lasciato le mura di Verona....!! E Forsa verona !!! [URL]',
#   '[regione] Veneto  [geo] 45.76 10.82\n'],
#  ['1',
#   'geolingit',
#   'E dringhiddi... Custa esti sa coccoi e corcoriga 😍😍 [URL]',
#   '[regione] Sardegna  [geo] 39.68 9.59\n'],
#  ['1',
#   'geolingit',
#   'Io e miei collaboratori che raccogliamo il sale po’ sa genti bamba de custu '
#   'logu. [URL]',
#   '[regione] Sardegna  [geo] 39.22 9.09\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ti se vecia vignuda 😱😱',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.79 13.54\n'],
#  ['1',
#   'geolingit',
#   'Io comunque ieri credo di aver scattato una foto a Saturno. "Eh, ma è '
#   'sfocata!" direte voi. Fa ti na foto a na roba a 9 anni luce de distansa co '
#   'na macchinetta fotografica. [URL]',
#   '[regione] Veneto  [geo] 45.4 12.38\n'],
#  ['1',
#   'geolingit',
#   "[USER] C'ha fasi co a voelu, basta c'a rumpu nen i cuiun...",
#   '[regione] Piemonte  [geo] 44.97 7.7\n'],
#  ['1',
#   'geolingit',
#   "da oggi potete anche chiamarmi MUZIO SCEMOla poco poco ma un po' si Edo "
#   'tses propi an piciu',
#   '[regione] Piemonte  [geo] 45.04 7.77\n'],
#  ['1',
#   'geolingit',
#   '[USER] Oh e metticelo un punto esclamativo ogni tanto. Così risulterai '
#   'ancora più perentorio, magari lo convinci il Cavaliere. E ci regala nu '
#   'bellu organigramma comm ce piace a nuje. Lo mettiamo in porta al posto di '
#   'Ospina. !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#   '[regione] Campania  [geo] 40.83 14.33\n'],
#  ['1',
#   'geolingit',
#   'Ma il problema sono i cattivoni che non producono, tengono tutto per sè e '
#   'non distribuiscono. Ma...Ma...Ma andì a ciapà i ratt! [URL]',
#   '[regione] Lombardia  [geo] 45.46 9.15\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] Chistu è suonnu Catarì 😊',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   '[USER] ci hai kappatu tie te nzurti Sula. Vidi kiru ka simmini ccoii. '
#   'Dialettu fattu a casa. 😘😅🥰 🇮🇹🇮🇹🇮🇹SEMPRE.',
#   '[regione] Puglia  [geo] 39.88 18.24\n'],
#  ['1',
#   'geolingit',
#   'Simu salentini dellu munnu cittadini e insieme a [USER].quaranta.real simu '
#   'veri Provinciali. Diime tie de du ede ca sta bieni? [USER] [USER] [USER] '
#   '[USER] @ [LOCATION] [URL]',
#   '[regione] Puglia  [geo] 40.26 18.19\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] '
#   '[USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] '
#   '[USER] [USER] [USER] [USER] [USER] [USER] [USER] 😊 Se vedemo domani se no '
#   'non sarà pe corpa mia 😂 Bonanotteee 😘',
#   '[regione] Lazio  [geo] 42.21 12.42\n'],
#  ['1',
#   'geolingit',
#   'Li mortacci de mi socera e de tutta la progenie sua de genti che la mattina '
#   'fanno macello e svegliano quelle che so insonni e se so addormite alle sei.',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] Era pattitu buonu puoi praticamente nun ha fattu nenti',
#   '[regione] Sicilia  [geo] 36.75 14.93\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] O mammuth...sè pagu scimpru 😂😂😂😂😂🐒🐒🐒🐒🗑🗑🗑🗑🗑🗑💩💩💩💩💩',
#   '[regione] Sardegna  [geo] 39.97 8.68\n'],
#  ['1',
#   'geolingit',
#   'Ma a me che mi frega di ciò che pensi di sapere e credi di nascondermi? Non '
#   "nde cherio intendere. Mi nd'affutto dedde. Mi la cherer dare ti la ponzo "
#   "issupra e s'altare ma non nde cherio intendere de inghirios de sa conca "
#   'tua. Il menestrello continua a farronzanare cussu è su prob',
#   '[regione] Sardegna  [geo] 40.33 9.3\n'],
#  ['1',
#   'geolingit',
#   "Complimenti per la trasmissione, mancu sulu s'è votato (per i non terroni, "
#   'nemmeno da solo si è votato) [URL]',
#   '[regione] Calabria  [geo] 39.27 16.27\n'],
#  ['1',
#   'geolingit',
#   'Quando si semina, si raccoglie! Ed io…raccolgo, raccolgo… e risemino pure '
#   '(a facc e chi c vo mal!)!!! #olive o#live @ [LOCATION] [URL]',
#   '[regione] Campania  [geo] 40.35 15.0\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] sempre. ce stanno du vecchietti a lavorà su sto cazzo '
#   'de ponte co na cariola e du pale. un ponte dove transitano un numero '
#   'impressionante de macchine',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] Ahhhh, qul '
#   "lì l'era n'elenc ad gnugnu???? Anduma bin, tses propi n'amisa! 😝😝😝😝",
#   '[regione] Piemonte  [geo] 45.07 7.67\n'],
#  ['1',
#   'geolingit',
#   'Mi piacerebbe che tutti quelli che fanno le pulci a pensieri e parole degli '
#   'altri, stessero attenti a spartizioni, costi, assunzioni, bilanci, '
#   'vitalizi, ed invece come sempre si ripete la storia della pagliuzza e la '
#   'trave. Av salut burdel',
#   '[regione] Emilia Romagna  [geo] 44.48 11.33\n'],
#  ['1',
#   'geolingit',
#   '[USER] Nce ponno arivà. So limitati dal 1900.',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] E semu chiossai! 😘',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   '[USER] Mentito un pochino si dai 8 miliardi ai benetton glieli ha dati il '
#   'suo ex governo Dai su fa nen parei',
#   '[regione] Piemonte  [geo] 45.07 7.67\n'],
#  ['1',
#   'geolingit',
#   '[USER] Una bella resa degli ucraini e vedi che la guerra finisce. Sti '
#   'ucraini che se vonno difenne hanno popo rotto. Viva la pace!!',
#   '[regione] Lazio  [geo] 41.57 12.85\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] Levate le ciavatte e vieni giù al secondo tempo te '
#   'offro na bira',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "Gaudio rinuncia all'incarico. Il prossimo candidato verrà scelto in diretta "
#   "a Live non è la D'Urso. Ps: fici bonu.",
#   '[regione] Calabria  [geo] 38.67 15.89\n'],
#  ['1',
#   'geolingit',
#   'Giornata iniziata bene Ho reso felice una persona e lei altrettanto me ♥️ '
#   "Buongiorno e buona domenica a tutti Facitv na caminata pi mia pur Ca c'è a "
#   'pei iornata',
#   '[regione] Calabria  [geo] 39.1 17.1\n'],
#  ['1',
#   'geolingit',
#   '[USER] Che popolo de cojoni che semo.. non aggiungo altro.',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'Sempre più convinta del detto “chi chiagn fott a chi rir”...vott a finì Stu '
#   'circ #sovip #tzvip #gfvip [URL]',
#   '[regione] Campania  [geo] 40.72 13.94\n'],
#  ['1',
#   'geolingit',
#   'Un Omo aprì er cortello e domannò a l’Olivo: Te dispiace de damme un '
#   '“ramoscello” simbolo de la Pace? No…no…disse l’Olivo nun scherzamo. perché '
#   'ho veduto,in più d’un’occasione, ch’er ramoscello è diventato un ramo e er '
#   'simbolo…un bastone. Trilussa #GiornataMondialeDellaPoesia [URL]',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] Vabbè ma a Milano pensano al “contestino” quando si mettono a '
#   'tavola! A nuje c’è piac a sustanz! 😉',
#   '[regione] Campania  [geo] 40.74 14.49\n'],
#  ['1',
#   'geolingit',
#   '▪️Rapresentâ la gno lenghe e reste une des robis plui significativis di fâ! '
#   '▪️Rappresentare la mia lingua rimane una delle cose più significative da '
#   'fare! ▪️Representing my language remains one of the most significant things '
#   'to do! #Friûl #Friuli #furlan #friulano [USER] [URL]',
#   '[regione] Friuli-Venezia Giulia  [geo] 46.04 13.05\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] Ghe ne' gera' tre quattro queo col cavaeo bianco xe resta' "
#   "ultimo...... megio' cussi povere bestie",
#   '[regione] Veneto  [geo] 45.4 12.38\n'],
#  ['1',
#   'geolingit',
#   '[USER] Non so se il perioduccio è passato, io ho dovuto aspettare un mese e '
#   "mezzo per averle entrambe, l'anteriore dopo un paio di settimane e la "
#   'posteriore quasi un mese dopo. Informati dal tuo gommaio, che a breve si '
#   'sgassa più di ora. Qui tira un vento diaccio che taglia il viso,❄️!',
#   '[regione] Toscana  [geo] 43.38 11.08\n'],
#  ['1',
#   'geolingit',
#   '[USER] ah, adesso gho capì! I te fa le consegne de bollicine direttamente '
#   'in pescheria….facile cussi 🤦🏻\u200d♂️😅',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.67 13.78\n'],
#  ['1',
#   'geolingit',
#   'Ma Ciccio Oppy ha davvero detto: “no Twitter non lo conosco”? Ma appena '
#   'esci ti prendo quei quattro capelli che hai in testa, e ti faccio arrivare '
#   'su Twitter tempo uno e uno. Mica stiamo lo stiamo perculando, difendendo '
#   'così per babbiare. #gfvip [URL]',
#   '[regione] Sicilia  [geo] 37.46 15.03\n'],
#  ['1',
#   'geolingit',
#   'ecco mi sembrava di averlo già visto... pazzesco un picio simile [URL]',
#   '[regione] Piemonte  [geo] 45.04 7.77\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] F.f.s.s. che m'e ' purtat a fra ncopp a Pusilleco si nun me "
#   "vuo cchiu ' bene?",
#   '[regione] Campania  [geo] 40.24 15.31\n'],
#  ['1',
#   'geolingit',
#   'L’unica moto che amo è quella che non scende dal cavalletto. Oh, per 18mila '
#   'la vendiamo eh. Intant, Cinno fa pulìd e va pianèn. A m’arcmand. [URL]',
#   '[regione] Emilia Romagna  [geo] 44.48 11.33\n'],
#  ['1',
#   'geolingit',
#   'Ma perché in ogni matrimonio, battesimo, cresima, compleanno ecc ecc c’è '
#   'sempre un mona che sta sempre fuori a fumare o a bere da solo? Ma sta casa '
#   'zio cane, casso veto a far la? Mona che non te si altro',
#   '[regione] Veneto  [geo] 45.47 10.71\n'],
#  ['1',
#   'geolingit',
#   '[USER] So popo stronza, artro che de coccio.',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'Hann mis a pazziell man e criature .... [URL]',
#   '[regione] Campania  [geo] 40.67 14.8\n'],
#  ['1',
#   'geolingit',
#   'Che corrente di pensiero hai zellè che si nu trmon?',
#   '[regione] Puglia  [geo] 41.09 16.87\n'],
#  ['1',
#   'geolingit',
#   '[USER] Un giorno di questi devo vení a pigliá un caffè da te...😂',
#   '[regione] Toscana  [geo] 43.66 10.36\n'],
#  ['1',
#   'geolingit',
#   '[USER] E si l’avevo capito...na bumma ca n’astruppia.',
#   '[regione] Sicilia  [geo] 37.46 15.03\n'],
#  ['1',
#   'geolingit',
#   '[USER] Speruma! Ma se anche fosse covid e non peggiorassi non sarebbe '
#   'male... Sarebbe più potente del richiamo',
#   '[regione] Piemonte  [geo] 44.95 8.41\n'],
#  ['1',
#   'geolingit',
#   'A l’é nen giornà Me lo tatuo sulla fronte [URL]',
#   '[regione] Piemonte  [geo] 45.07 7.67\n'],
#  ['1',
#   'geolingit',
#   'Il pogaridari va scandito bene, sillaba dopo sillaba. PO GA RI DA RI.',
#   '[regione] Sardegna  [geo] 39.22 9.09\n'],
#  ['1',
#   'geolingit',
#   '[USER] gheto mia fatto caso che stasera [USER] sapeva già a inizio puntata '
#   'che avrebbe conosciuto più tardi la moglie del nuovo campione di '
#   '#DontForgetTheLyrics 😂😂',
#   '[regione] Veneto  [geo] 45.31 11.12\n'],
#  ['1',
#   'geolingit',
#   'La ghi seu de Quartu ri partu @ [LOCATION] [URL]',
#   '[regione] Sardegna  [geo] 39.21 9.27\n'],
#  ['1',
#   'geolingit',
#   "No vabbè N'agg idè Sempre peggio 😬🤦🏻\u200d♀️",
#   '[regione] Campania  [geo] 41.1 13.91\n'],
#  ['1',
#   'geolingit',
#   '[USER] Chi dici, u mi riri nienti 🤦🏻\u200d♂️😅',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   "...ottimo esempio di televisione de 'noantri, .... tipo coda a'vaccinara, "
#   "cacio e pepe, ce famo du spaghi...bastano un paio de' scarpe bbone e poi "
#   "gira' tutto er monno... [URL]",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'marò sta settimana a lavoro me ga copaaa',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.78 13.07\n'],
#  ['1',
#   'geolingit',
#   '[USER] Si zita, maritata, hai figghi, cuntami ti tia c’à io si mi '
#   'd’addumanni ti cuntu ti mia 😘',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   "[USER] Sugnu d'accordo con te ma avemu u sinnaco con lui",
#   '[regione] Sicilia  [geo] 37.33 14.9\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] Cangia ddha cazzu de foto profilo però! Cu lu '
#   'frittivendolo subra la moto 😂😂😂',
#   '[regione] Puglia  [geo] 40.41 18.18\n'],
#  ['1',
#   'geolingit',
#   '[USER] Cetto, mica sugnu a Catania!',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] Forse coi cannoletti la convinciamo. Comunque a me '
#   'regalarono un corso de pasticceria anni fa, li feci i cannoli, ma era '
#   'frequentato da soli single maschi, che pensavano che la cucina era roba pe '
#   "rimorchià. N'ho capito n'cazzo co tutto quel testosterone e nme ricordo "
#   "n'cazzo.",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "Alla faccia e chi tene a guerra n'capa, che m' fanno venire a guerra n'capa "
#   "da domare e forza best brau ed i suoi °! 😍💪🕺💪😍💖E vafancul' a uerr'! 🤕😢🤕 @ "
#   '[LOCATION] [URL]',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   'quelli che quando si mettano un vestito novo INCIGNANO; quelli che son '
#   "BRIAI TEGOLI e BAGNATI MEZZI; quelli che d'estate GRONDANO dar sudore e "
#   "d'inverno PIPANO DAR FREDDO e s' IMBAUCCANO per un PIGLIÀ FRESCO. Quelli "
#   'che ar TOCCO vanno a DESINÀ; .......... continua',
#   '[regione] Toscana  [geo] 43.5 10.15\n'],
#  ['1',
#   'geolingit',
#   'Luca tu tien e qualità ma comm aggia fa tu m faij asci pazz #LDA',
#   '[regione] Campania  [geo] 40.92 14.43\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ocio ...attrezzati con qualche damigiana de vin bon ...e una griglia '
#   'per arrostire costesine ... Ma quella carne di topo del kebab ...Maiiiiiii '
#   '!!!',
#   '[regione] Veneto  [geo] 45.45 11.74\n'],
#  ['1',
#   'geolingit',
#   '[USER] ma pe tornà ar gabbio che cazzo ha combinato?',
#   '[regione] Lazio  [geo] 41.88 12.22\n'],
#  ['1',
#   'geolingit',
#   "Aggiornamento meteo (lo so non frega a nessuno) tira vento diaccio e c'è "
#   'sole 🤷🏻',
#   '[regione] Toscana  [geo] 43.89 10.78\n'],
#  ['1',
#   'geolingit',
#   "[USER] Quanno te vedo pe l'occhi mia è sempre festa 😍",
#   '[regione] Lazio  [geo] 41.58 12.65\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Là sì che si sta bene! Lei lo sa... poareta...',
#   '[regione] Veneto  [geo] 45.62 11.55\n'],
#  ['1',
#   'geolingit',
#   'Se la galina tase’sse nissun savaria che la ga fato l’ovo.Mi raccomando '
#   'fate i bravi,buona giornata a tutti voi.',
#   '[regione] Veneto  [geo] 45.3 11.82\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Mi sa proprio di sì. N’ze guarda!',
#   '[regione] Toscana  [geo] 43.44 11.9\n'],
#  ['1',
#   'geolingit',
#   '[USER] La stava prendendo ma Buffon glielo ha impedito...nun sfruculiamm '
#   "anche quando non ce n'è motivo jamm",
#   '[regione] Campania  [geo] 40.9 14.48\n'],
#  ['1',
#   'geolingit',
#   'Two days of hard working (and drinking)! Doi dis di bon lavôr (e bevi cun '
#   'grinte cence fâ finte)! Due giornate di lavoro sodo (e sodo bere)! @ '
#   '[LOCATION] [URL]',
#   '[regione] Friuli-Venezia Giulia  [geo] 46.16 13.19\n'],
#  ['1',
#   'geolingit',
#   '[USER] Che poi anche in città no xe mal. [URL]',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.67 13.78\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ma chi è sto pirata der cazzo !! Scritto in dialetto e si nun je sta '
#   "bene mo venisse a di' che je do un destro in bocca puro cor braccio rotto "
#   '!!',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'Cosa voglian fa? Andá su Marte nel dumilatrenta? Ma se un son boni nemmeno '
#   "a curá un infruenza? Ma levatevi di 'ulo....",
#   '[regione] Toscana  [geo] 43.64 10.63\n'],
#  ['1',
#   'geolingit',
#   'Me state a fa salì un cazzo di nervoso che manco quanno ho scoperto il mio '
#   'ex che me metteva le corna! Mortacci vostra mortacci #INPS',
#   '[regione] Lazio  [geo] 42.65 12.18\n'],
#  ['1',
#   'geolingit',
#   'A Reggio Calabria, si dice : na vota si futti a vecchia, nto culu attia! 😎 '
#   'Però parecchi si sono rammoliti, i futtiru tri voti e ora i futtunu a '
#   'quarta, stranissimo, mah! 😇',
#   '[regione] Calabria  [geo] 38.1 15.74\n'],
#  ['1',
#   'geolingit',
#   'Cossa me ciàva Che pochi se acòrzi Quel che me scrivo ? I dormi, forsi Sarò '
#   'el loro incubo, O sogno, chi sa ? Opùr son morto, Un fantasma che scrivi '
# ...
#   '[regione] Puglia  [geo] 40.86 16.84\n'],
#  ['1',
#   'geolingit',
#   'Ma quindi non posso andare a trovare la mia morosa? E me come fo ades? '
#   'Incredibile!!!',
#   '[regione] Lombardia  [geo] 45.5 9.84\n'],
#  ['1',
#   'geolingit',
#   '[USER] Nun t puort chiu ….. , Ce sfrantumat a UALLERA',
#   '[regione] Campania  [geo] 40.83 14.33\n'],
#  ['1',
#   'geolingit',
#   '[USER] Pe aggrappasse a qualcosa.. pe dasse un tono',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ma non te ce mette a annaje sotto a quella poraccia, che lo fa solo '
#   "pe attirà l'attenzione che nun saaa ncula nessuno.",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "Mi sto bevendo un #succo d'arancia rossa corretto con il #gin ... devo dire "
#   'che che xè proprio bon 🤣',
#   '[regione] Veneto  [geo] 45.68 11.74\n'],
#  ['1',
#   'geolingit',
#   'me la lego ar dito, m’hai detto na cazzata [URL]',
#   '[regione] Lazio  [geo] 41.65 12.5\n'],
#  ['1',
#   'geolingit',
#   '[USER] tin bota Stefano presidente mi perdoni il tono informale un '
#   'abbraccio , anche se asintomatico la vicinanza di un amico che non vedi da '
#   'anni ma che ha sempre fiducia in te',
#   '[regione] Emilia Romagna  [geo] 44.64 10.89\n'],
#  ['1',
#   'geolingit',
#   '[USER] Lu spilu si dice dalle mie parti! Buona cena 👍',
#   '[regione] Puglia  [geo] 40.41 18.18\n'],
#  ['1',
#   'geolingit',
#   "Ma quando li vedi cresce, ti senti un po' zia ☺️ anche se sempre da "
#   'lontano, sembra comunque che fa parte di te della tua vita, te fa senti '
#   "pure vecchia mortacci 🤭😄 poi te vie' da fa'ste foto 🥺 Tvb [USER] ❤️ [URL]",
#   '[regione] Lazio  [geo] 41.98 12.69\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ma robe da matti.... Ti me gà svoltà a giornada🤣🤣🤣',
#   '[regione] Veneto  [geo] 45.4 12.38\n'],
#  ['1',
#   'geolingit',
#   "[USER] mo a ipsos je tocca richiama' tutti quelli del sondaggio e fa na "
#   'colletta',
#   '[regione] Lazio  [geo] 41.26 13.43\n'],
#  ['1',
#   'geolingit',
#   '[USER] Fatte na domanda e datte na risposta 😂',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'La figlia ha i capelli rossi? Perché qui a Reggio si dice: al più bon di '
#   "ross l'ha bute' so peder in t'al poss #QuartoGrado",
#   '[regione] Emilia Romagna  [geo] 44.69 10.63\n'],
#  ['1',
#   'geolingit',
#   '[USER] Entra da noi [URL] e megl stamm a snti ahahahahha',
#   '[regione] Campania  [geo] 40.93 14.48\n'],
#  ['1',
#   'geolingit',
#   "Dhu fetusu i diu, ava capiri chi u ciocculattu e' bellu, e si tu dununu "
#   'senza sordi, dhu fetusu i diu ava considerari a bellezza du me trovaghiu '
#   'duci duci (amore = intelligenza e sincerità) Se NO, scrivu su facebook e '
#   'fazzu capiri quantu guadagna dhu fetusu i diu essennu mutu',
#   '[regione] Sicilia  [geo] 38.15 14.87\n'],
#  ['1',
#   'geolingit',
#   'E le puppe. Puppe e culo arrivi dovunque [URL]',
#   '[regione] Toscana  [geo] 43.88 11.09\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] 7 gradi sotto media... Altroché umido... A dicembre vien da '
#   'mi a ciapar al sol in giardino... Visto che i sarà 20gradi',
#   '[regione] Veneto  [geo] 46.02 12.09\n'],
#  ['1',
#   'geolingit',
#   '[USER] La Sòla direbbe la qualsiasi bischerata , (come si dice in Toscana ) '
#   ',per poter interagire con Aldo ,ma lui non ci casca , gli ha sparlato '
#   'dietro 2 mesi gli ha detto che non lo sopporta ed ora cosa pretende? Sòla '
#   "tieniti il tuo Attore ,con Aldo non c'è trippa per gatti .",
#   '[regione] Toscana  [geo] 43.82 10.61\n'],
#  ['1',
#   'geolingit',
#   "[USER] Dunde ne vegni Duve l'è ch'ane... Io ne percorro spesso una che "
#   "dall'aurelia mi porta al mare😎",
#   '[regione] Liguria  [geo] 44.32 9.31\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ehhh avoja che già l’avemo chiamati tutti [URL]',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] Mai ciapà soeo che 2 anca a superiora co ndavo al doposcuola el. '
#   'Pomeriggio a me batteva come un tamburo 😂😂iero vivace',
#   '[regione] Veneto  [geo] 45.4 12.17\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Deve rasarsi lautaro... Tene a capu ca pare na bitta te sotta '
#   'u portu 🤣🤣🤣',
#   '[regione] Puglia  [geo] 40.04 18.01\n'],
#  ['1',
#   'geolingit',
#   '[USER] Bella zovena alle na parolla grossa 🤣🤣🤣',
#   '[regione] Liguria  [geo] 44.44 8.88\n'],
#  ['1',
#   'geolingit',
#   "[USER] No so' gnanca cossa berghe sora",
#   '[regione] Veneto  [geo] 45.39 11.89\n'],
#  ['1',
#   'geolingit',
#   "Ma kabak è quello che dovevamo prendere l'anno scorso e che poi ci ha "
#   "ca'ato lì?",
#   '[regione] Toscana  [geo] 43.85 10.26\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ma nn ha nemmeno la personalità per avere questo ruolo. Doveva '
#   'andare nel reparto contabilità in uno dei supermercati di suo padre a fare '
#   'buste paga. L è an bun ad gnint',
#   '[regione] Lombardia  [geo] 45.0 10.73\n'],
#  ['1',
#   'geolingit',
#   '[USER] Va curct tu e iddru Su Calippo i omu',
#   '[regione] Calabria  [geo] 39.1 17.1\n'],
#  ['1',
#   'geolingit',
#   "[USER] Poche ore, na smana l'è durada...",
#   '[regione] Emilia Romagna  [geo] 44.8 11.67\n'],
#  ['1',
#   'geolingit',
#   '[USER] Magari si riuscisse... stamm nguaiat!! So pure assaje!!',
#   '[regione] Campania  [geo] 41.15 14.78\n'],
#  ['1',
#   'geolingit',
#   '[USER] Io pe non famme manca niente me so preso pure il covid🤩',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] Ambe. Si. Me tocca datte ragione. Na pandemia è '
#   'difficile da negà.',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] L’è minga vera. I can veuren sta cunt i lur padrun. Anca in '
#   'un meter quader. Traduzione: non è vero. I cani vogliono stare con i loro '
#   'padroni. Fosse anche in un metro quadro.',
#   '[regione] Lombardia  [geo] 45.46 9.15\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ghe sta dei! Altrimenti cossa gavessi fatto in vimdtm... Xe come '
#   'casa',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.59 13.77\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ciao Fradeeto, domenega prossima 14 ore 17.30 se par ti no ghe xe '
#   'problemi mi ea Federica vegnimo 👍🏻👍🏻👍🏻',
#   '[regione] Veneto  [geo] 45.4 12.38\n'],
#  ['1',
#   'geolingit',
#   "[USER] Non lo ponno chiamà co n'antro nome?",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "[USER] Teooooo: m'è venied un idea!!! Inveci de anda a mosca peüdet mia "
#   'andá a Disneyland??? Cazzo, fai i selfie cu topolino, paperino e tüti gli '
#   'altri personaggi famosi!! Sai quanti laajk su tvitür e feesbuch?? By the '
#   'way: ghet iest El Bissi a crema???',
#   '[regione] Lombardia  [geo] 45.29 9.84\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] Uhhhh. Sono ciuccia. Che ci posso fare ! Pultroppo. O '
#   'amata essere sierata. Meglio sierata e non schierata con questa '
#   'manifestazione pagliacciata. Ha proposito, mhe,quandi siete?',
#   '[regione] Puglia  [geo] 40.65 16.78\n'],
#  ['1',
#   'geolingit',
#   '[USER] Si, ma vini de cartelle era, vistu lu casinu ca ave cumbinatu🤣🤣',
#   '[regione] Puglia  [geo] 40.11 18.29\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Ata fa na fine e merd tutt e duje.Tornare dalla stessa fogna '
#   'dalla quale siete usciti. Da no euro a europeista, che lota ca si!',
#   '[regione] Campania  [geo] 40.62 14.93\n'],
#  ['1',
#   'geolingit',
#   '"Cu n\'uocchio frije \'o pesce e cu n\'ato guarda \'a gatta." Ecco, oggi è '
#   "proprio così: n' uocchio alla #Ferrari e cu n' ato guardo #EmpoliNapoli Ata "
#   "passà nient'!!",
#   '[regione] Campania  [geo] 40.92 14.13\n'],
#  ['1',
#   'geolingit',
#   '[USER] SONO STATO UN COGLIONE AD OFFENDERTI NON MI PERDONERAI MAI FORSE CI '
#   'SPERO HO ESAGERATO LO AMMETTO MA AVEVO PERSO LA TESTA E LA GHIGNA ANCORA UN '
#   'ALTRA VOLTA DOPO TUTTO O SE VOET VENDICAT VENDICHET DE CHEL CHE TO DIT PER '
#   "ME L'È AMÒ CULPA DE",
#   '[regione] Lombardia  [geo] 45.53 10.22\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Dai, stai buono che sono bresco come pochi. 😭',
#   '[regione] Emilia Romagna  [geo] 44.64 10.89\n'],
#  ['1',
#   'geolingit',
#   '[USER] Perfetto...sai benissimo che ho sempre avuto quella allegra capacità '
#   'di scorgere qualche mossa prima del mio avversario...e siccomu scemi '
#   'n’avemu na miriade già m’ummagginu...',
#   '[regione] Sicilia  [geo] 37.46 15.03\n'],
#  ['1',
#   'geolingit',
#   '#BraveAndBeautiful Dove starà andando il fetente? Ma ovviamente da Sühan! '
#   'MANNAGG A TUTT COS!',
#   '[regione] Campania  [geo] 40.93 14.44\n'],
#  ['1',
#   'geolingit',
#   "Li morta**i tua e de chi 'nte c'ha mannato co na mano arzata [URL]",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "[USER] Che sciura cun i danée, al grand hotel l'è naia",
#   '[regione] Lombardia  [geo] 45.86 8.7\n'],
#  ['1',
#   'geolingit',
#   'El bar sotto el me studio carissimi [USER] e [USER] oggi me gà preparà sate '
#   'de gaina lesse e Valpolicella 🤩🤩🤩',
#   '[regione] Veneto  [geo] 45.39 11.89\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ma o ver è iss! Che rattuso 🤣🤣',
#   '[regione] Campania  [geo] 40.79 14.43\n'],
#  ['1',
#   'geolingit',
#   '[USER] A si biri cun saludi.',
#   '[regione] Sardegna  [geo] 38.95 8.72\n'],
#  ['1',
#   'geolingit',
#   'Labai chi ri castiu e no ri biu [USER] [USER] [USER] [USER] 😁😂😂😂😂😂 [URL]',
#   '[regione] Sardegna  [geo] 39.27 9.33\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ma statt a cas statt. Facciamo a meno di un carico a chiacchiere, '
#   'come si dice da noi. Buona fine d’anno a tutti 🍀',
#   '[regione] Puglia  [geo] 41.09 16.87\n'],
#  ['1',
#   'geolingit',
#   "[USER] J'è partita la ciavatta",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'ma sto trimone cesso all’una co sto trapano',
#   '[regione] Puglia  [geo] 41.09 16.87\n'],
#  ['1',
#   'geolingit',
#   "[USER] faje l'abbacchio ar forno",
#   '[regione] Lazio  [geo] 41.88 12.22\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] Maddai, se sta na bomba. Io sto a uscì cor chiodo.',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'Vabbè dai in Calabria non ci si annoia...zona rossa perchè se ci ammaliamo '
#   'ci vuole " \'nu corniceddru" poi arancione " \'namu stari ara casa" allerta '
#   'gialla "pirchì chijova e \'n\'allagamu ccu ri cazzi" e "mò \'u terrimotu" '
#   '"Caru duijmila e vinti potissi ijri a farinculu fuijennu?"',
#   '[regione] Calabria  [geo] 39.1 17.1\n'],
#  ['1',
#   'geolingit',
#   '[USER] Magari avessero magnato su sciuti per na spremuta😂😂😂😂',
#   '[regione] Puglia  [geo] 40.04 18.01\n'],
#  ['1',
#   'geolingit',
#   '[USER] Varda se ti trovi dei brustangoi così poi femo il risotto #veneto',
#   '[regione] Veneto  [geo] 45.53 11.89\n'],
#  ['1',
#   'geolingit',
#   'Boia raga, ho trovato du euro...! In Italia, con quer che si guadagna, mi '
#   "'apitasse tutti i giorni, avrei guasi guadagnato uno stipendio l'anno....",
#   '[regione] Toscana  [geo] 43.66 10.36\n'],
#  ['1',
#   'geolingit',
#   'Ghe sboro che caldo',
#   '[regione] Veneto  [geo] 45.46 12.5\n'],
#  ['1',
#   'geolingit',
#   'Ij sul na cos vulev ricr: ALLA FACCIA DEL MIO EX 😈😈😈',
#   '[regione] Campania  [geo] 40.92 14.51\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Cesti un altru prodottu mera bonu, dei usu su graniti, du '
#   'bendinti a sa Conad, du usanta mei ristorantisi, se olisti ti mandu sa '
#   'fotu, è fattu de granu teneru',
#   '[regione] Sardegna  [geo] 39.19 8.41\n'],
#  ['1',
#   'geolingit',
#   'L’attaccante più sopravvalutato di SEMPRE in ITALIA Uno scuorno condivida '
#   'con Higuain il record All-time in Serie A ( Solo perché segnó 13 rigori eh) '
#   'Si ritirasse domani dalla Nazionale, STA CIOFECA #ItaliaMacedonia [URL]',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   "[USER] Mi g'ho 38 ann... El me omm l'ha inscì da supurtàa anc'amó. 😁 Mi si "
#   'perdoni il vernacolo incerto.',
#   '[regione] Lombardia  [geo] 45.62 9.32\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ma mille grazie GNARO 😜',
#   '[regione] Lombardia  [geo] 45.53 10.22\n'],
#  ['1',
#   'geolingit',
#   "[USER] U le' quesci cumme u zeneise...",
#   '[regione] Liguria  [geo] 44.32 9.31\n'],
#  ['1',
#   'geolingit',
#   'Preparato il contorno per stasera "Mulinciani ccu '
#   'pummadoru,agghiju,fogghjia \'i lauru,pipurussu"😋 [URL]',
#   '[regione] Calabria  [geo] 39.1 17.1\n'],
#  ['1',
#   'geolingit',
#   "[USER] Orpo ,allora il ricatto e l'estorsione funziona con i conigli e chi "
#   'non si può permettere i tamponi o di restare a casa.',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.67 13.78\n'],
#  ['1',
#   'geolingit',
#   '[USER] Non sai più che caxxo inventatte pe prende voti ! Poraccia',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] E se ghea gò fatta mi ...',
#   '[regione] Veneto  [geo] 45.39 11.89\n'],
#  ['1',
#   'geolingit',
#   '[USER] El Francesco l’ha pugiaa i culunei in Argentina quand l’era vescus. '
#   'L’è mej tasè, da ma trà',
#   '[regione] Lombardia  [geo] 45.83 8.8\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Andrea non passa mai... Stamm accussi da 40 anni '
#   '(personalmente)',
#   '[regione] Campania  [geo] 40.88 14.12\n'],
#  ['1',
#   'geolingit',
#   '"Andate a friggere le panelle" MA TI BRUCIO NELL\'OLIO BOLLENTE DI QUESTE '
#   'PANELLE. VA A SCASSACI A MINCHIA A NAVUTRA BANNA',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] Ma che hai calcolato oh ahahahah no no mica vojo '
#   'aspetta ancora che semo matti 😂',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] Ma mettemo nel novero pure i consorti. Soprattutto er '
#   'mio che semo un nucleo monoreddito.',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "[USER] Nel nome del padre del figlio e dello spirito santo. T'é fatt a croc "
#   'a primma matin',
#   '[regione] Campania  [geo] 40.81 14.06\n'],
#  ['1',
#   'geolingit',
#   '[USER] Quanno ce vo ce vo ... è liberatorio🤣',
#   '[regione] Lazio  [geo] 41.88 12.97\n'],
#  ['1',
#   'geolingit',
#   '[USER] Chista spanò ri cirivieddu 😂😂😂😂😂',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   'Belin, manco da morti se queta... [URL]',
#   '[regione] Liguria  [geo] 44.44 8.88\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] '
#   '[USER] Distratto. No. Ieri no gho vu tempo e anco son ntele base (no come '
#   "l'omonimo che follegia). Ma sento cosa posso far. Era, [USER] ?",
#   '[regione] Veneto  [geo] 45.15 11.3\n'],
#  ['1',
#   'geolingit',
#   '[USER] Belin coerenza, sono riusciti in 2anni ad annichilire un popolo e '
#   'fargli odiare quello che gli sta vicino con belinate del genere. Ormai la '
#   'porta è aperta un popolo di ubriachi cronici continua a bere fino alla '
#   'morte. Come abbiamo fatto a diventare così? Lo dice la TV...',
#   '[regione] Liguria  [geo] 44.44 8.88\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Incredibilmente, alla lunga, ne sono usciti bene, rispetto '
#   'agli esordi svogliati. Sui danè, ta ghet resùn.',
#   '[regione] Lombardia  [geo] 45.62 9.32\n'],
#  ['1',
#   'geolingit',
#   'Ma va ben a cagher Pino',
#   '[regione] Emilia Romagna  [geo] 44.28 11.25\n'],
#  ['1',
#   'geolingit',
#   'Che domenica è senza : SO MAISTA’ “U CANNOLU SICILIANU” Quannu iu era '
#   'carusu mo matri priparava, pi Carnalivari e pi festi chiù ‘mpurtanti, '
#   'chiddi ca su i cosi duci siciliani chiù canusciuti e disidirati ‘nto munnu: '
#   'i cannoli siciliani. [URL]',
#   '[regione] Sicilia  [geo] 37.78 15.2\n'],
#  ['1',
#   'geolingit',
#   'Berlusconi e positivo dove e sciut',
#   '[regione] Puglia  [geo] 40.76 17.1\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Ara riversa Dui gniffule ara riversa 😂😂😂 #ilunatici',
#   '[regione] Calabria  [geo] 39.1 17.1\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] [USER] Quando decideva di giocarla sul serio, ce n'erano "
#   "pochi all'altezza du [USER] nesciu! 😉",
#   '[regione] Puglia  [geo] 40.11 18.29\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ieri fava na fraid!!',
#   '[regione] Piemonte  [geo] 44.95 8.41\n'],
#  ['1',
#   'geolingit',
#   'Prof: dove siete arrivati in storia? Stud: a semo rivai a ea simia che copa '
#   "l'omo co l'osso!",
#   '[regione] Veneto  [geo] 45.39 11.89\n'],
#  ['1',
#   'geolingit',
#   "[USER] C'è vonno altri sei mesi pe faie sviluppa er cervello",
#   '[regione] Lazio  [geo] 41.89 12.54\n']]

# %%
# generate prompts based on task and text
preds = []
for input in inputs:
  id = input[0]
  task = input[1]
  text = input[2]
  expected_output = input[3]

  instruction = task_to_prompt(task)
  prompt = generate_prompt_pred(instruction, text) #pay attention that the input is not too long (over the max length of your model)

  # tokenization
  tokenized_inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True).to(model.device)

  # inference
  with torch.no_grad():
    gen_outputs = model.generate(
      **tokenized_inputs,
      return_dict_in_generate=True,
      output_scores=True,
      max_new_tokens=256, # how many token (wordpieces) to add to the input prompt. In ExtremITA answers are short
      do_sample=False # we do not need any sampling or beam seach. We just need the "best" solution, so the greedy search is fine: https://huggingface.co/blog/how-to-generate
    )

    # decoding and printing
    for i in range(len(gen_outputs[0])):
      output = tokenizer.decode(gen_outputs[0][i], skip_special_tokens=True)
      if "### Risposta:" in output:
        response = output.split("### Risposta:")[1].rstrip().lstrip()
      else:
        response = "UNK"

      print(text)
      print(f"\t {expected_output} \t {response}")
      print(50*"*")
# Out:
# [USER] Mortacci, na roba che nse po' vede, Por, na cacata rara.
# 	 [regione] Lazio  [geo] 41.89 12.54
#  	 [regione] Lazio [geo] 41.89 12.54
# **************************************************
# [USER] In Liguria diciamo: CIU INLA’ U GHE CIOSU..!😂😂😂🤡🤡🤡
# 	 [regione] Liguria  [geo] 43.9 8.0
#  	 [regione] Liguria [geo] 44.44 8.88
# **************************************************
# [USER] Uuuuuuaaaaa.... [USER] si nu bell cafè cu nu bicchier d’ acqua minerale ‘ngopp a na nave e crocier 🤣🤣🤣🤣🌹🌹🌹🌹
# 	 [regione] Campania  [geo] 40.85 14.24
#  	 [regione] Campania [geo] 40.85 14.24
# **************************************************
# [USER] [USER] Boffe a dui a dui finu caddivientanu rispari Pure così
# 	 [regione] Sicilia  [geo] 38.13 13.34
#  	 [regione] Sicilia [geo] 37.46 15.03
# **************************************************
# [USER] Anvedi andò stai. La prossima volta dimmelo pe tempo che te faccio un saluto.
# 	 [regione] Lazio  [geo] 41.89 12.54
#  	 [regione] Lazio [geo] 41.89 12.54
# **************************************************
# Sta Mejo lei che [USER] #nzonzi ma de che stamo a parlà [URL]
# 	 [regione] Lazio  [geo] 41.89 12.54
#  	 [regione] Lazio [geo] 41.89 12.54
# **************************************************
# [USER] Certo che con questo approccio così "incisivo" cascheranno tutte ai suoi piedi! (Detto siciliano un po' edulcorato: si l'avissiru a'mangiari i canuzzi Nichi Nichi!) 🤮🤮🤮
# 	 [regione] Sicilia  [geo] 37.46 14.01
#  	 [regione] Sicilia [geo] 38.13 13.34
# **************************************************
# Mia madre "Portate via na felpa che se fa freddo..." Io "Mama ghe xe 70 gradi all'ombra e anche se fosse dove a impìroi che ea borsa xe drìo sciopàre?" Le mie solite risposte pacate.
# 	 [regione] Veneto  [geo] 45.23 11.75
#  	 [regione] Veneto [geo] 45.4 12.38
# **************************************************
# [USER] [USER] [USER] [USER] [USER] [USER] [USER] Poi se nn so più de tre piotte nn vince....io gioco 3 euro pe vince 10 🤣🤣🤣🤣🤣
# 	 [regione] Lazio  [geo] 41.65 12.5
#  	 [regione] Lazio [geo] 41.89 12.54
# **************************************************
# [USER
#  	 [regione] Lazio [geo] 41.89 12.54
# **************************************************
# Se tutto va per il verso giusto (è fazzu corna 🤘 tuccannu ferro) tu non ti devi avvicinare al Cibali neanche in prossimità del 300km di perimetro. [URL]
# 	 [regione] Sicilia  [geo] 37.46 15.03
#  	 [regione] Sicilia [geo] 37.46 15.03
# **************************************************
# [USER] u capivu, mi va fazzu a doccia 😂😂😂
# 	 [regione] Sicilia  [geo] 38.13 13.34
#  	 [regione] Sicilia [geo] 37.46 15.03
# **************************************************
# [USER] Se volete vi svelo il segreto. Però domani lo mettete in prima pagina. "An n'è menga tant biand" (non è tanto biondo) vuol dire che non si è propensi a farsi fregare.
# 	 [regione] Emilia Romagna  [geo] 44.58 10.85
#  	 [regione] Lombardia [geo] 45.46 9.15
# **************************************************
# [USER] [USER] [USER] [USER] [USER] [USER] [USER] Mi meraviglio di [USER], che risponde a questa gentaglia. Il signore simone continua a fare o gall n'cop a munnezz...
# 	 [regione] Campania  [geo] 40.85 14.24
#  	 [regione] Campania [geo] 40.85 14.24
# **************************************************
# "Post mortem nihil est ipsaque mors nihil, velocis spatii meta novissima" ... che vor dì dopo la morte non esiste più nulla e ce ne s'ha per 3 caate
# 	 [regione] Toscana  [geo] 42.85 11.48
#  	 [regione] Lazio [geo] 41.89 12.54
# **************************************************
# Sul figur d merd... Si stanno arrampicando ovunque ci si possa arrampicare 🤣🤣🤣🤣 [URL]
# 	 [regione] Campania  [geo] 41.1 13.91
#  	 [regione] Campania [geo] 40.85 14.24
# **************************************************
# [USER] boja fauss! per na volta che l'huma cumbina'... 😡
# 	 [regione] Piemonte  [geo] 45.07 7.67
#  	 [regione] Lombardia [geo] 45.46 9.15
# **************************************************
# [USER] Gheto mai senti' parlar de la politica?
# 	 [regione] Veneto  [geo] 45.23 11.75
#  	 [regione] Lazio [geo] 41.89 12.54
# **************************************************
# Buon campionato butei...e forsa Verona e kumbulla va in mona ti e tutti quei che hanno lasciato le mura di Verona....!! E Forsa verona !!! [URL]
# 	 [regione] Veneto  [geo] 45.76 10.82
#  	 [regione] Veneto [geo] 45.4 12.38
# **************************************************
# E dringhiddi... Custa esti sa coccoi e corcoriga 😍😍 [URL]
# 	 [regione] Sardegna  [geo] 39.68 9.59
#  	 [regione] Campania [geo] 40.85 14.24
# **************************************************
# Io e miei collaboratori che raccogliamo il sale po’ sa genti bamba de custu logu. [URL]
# 	 [regione] Sardegna  [geo] 39.22 9.09
#  	 [regione] Sardegna [geo] 40.01 9.25
# **************************************************
# [USER] Ti se vecia vignuda 😱😱
# 	 [regione] Friuli-Venezia Giulia  [geo] 45.79 13.54
#  	 [regione] Piemonte [geo] 45.07 7.67
# **************************************************
# Io comunque ieri credo di aver scattato una foto a Saturno. "Eh, ma è sfocata!" direte voi. Fa ti na foto a na roba a 9 anni luce de distansa co na macchinetta fotografica. [URL]
# 	 [regione] Veneto  [geo] 45.4 12.38
#  	 [regione] Lazio [geo] 41.89 12.54
# **************************************************
# [USER] C'ha fasi co a voelu, basta c'a rumpu nen i cuiun...
# 	 [regione] Piemonte  [geo] 44.97 7.7
#  	 [regione] Sardegna [geo] 40.01 9.25
# **************************************************
# da oggi potete anche chiamarmi MUZIO SCEMOla poco poco ma un po' si Edo tses propi an piciu
# 	 [regione] Piemonte  [geo] 45.04 7.77
#  	 [regione] Sardegna [geo] 40.01 9.25
# **************************************************
# [USER] Oh e metticelo un punto esclamativo ogni tanto. Così risulterai ancora più perentorio, magari lo convinci il Cavaliere. E ci regala nu bellu organigramma comm ce piace a nuje. Lo mettiamo in porta al posto di Ospina. !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 	 [regione] Campania  [geo] 40.83 14.33
#  	 [regione] Campania [geo] 40.85 14.24
# **************************************************
# Ma il problema sono i cattivoni che non producono, tengono tutto per sè e non distribuiscono. Ma...Ma...Ma andì a ciapà i ratt! [URL]
# 	 [regione] Lombardia  [geo] 45.46 9.15
#  	 [regione] Lombardia [geo] 45.46 9.15
# **************************************************
# [USER] [USER] [USER] Chistu è suonnu Catarì 😊
# 	 [regione] Sicilia  [geo] 38.13 13.34
#  	 [regione] Sicilia [geo] 37.46 15.03
# **************************************************
# [USER] ci hai kappatu tie te nzurti Sula. Vidi kiru ka simmini ccoii. Dialettu fattu a casa. 😘😅🥰 🇮🇹🇮🇹🇮🇹SEMPRE.
# 	 [regione] Puglia  [geo] 39.88 18.24
#  	 [regione] Sicilia [geo] 37.46 15.03
# **************************************************
# Simu salentini dellu munnu cittadini e insieme a [USER].quaranta.real simu veri Provinciali. Diime tie de du ede ca sta bieni? [USER] [USER] [USER] [USER] @ [LOCATION] [URL]
# 	 [regione] Puglia  [geo] 40.26 18.19
#  	 [regione] Puglia [geo] 40.41 18.18
# **************************************************
# [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] 😊 Se vedemo domani se no non sarà pe corpa mia 😂 Bonanotteee 😘
# 	 [regione] Lazio  [geo] 42.21 12.42
#  	 [regione] Lazio [geo] 41.89 12.54
# **************************************************
# Li mortacci de mi socera e de tutta la progenie sua de genti che la mattina fanno macello e svegliano quelle che so insonni e se so addormite alle sei.
# 	 [regione] Lazio  [geo] 41.89 12.54
#  	 [regione] Lazio [geo] 41.89 12.54
# **************************************************
# [USER] Era pattitu buonu puoi praticamente nun ha fattu nenti
# 	 [regione] Sicilia  [geo] 36.75 14.93
#  	 [regione] Sicilia [geo] 37.46 15.03
# **************************************************
# [USER] [USER] O mammuth...sè pagu scimpru 😂😂😂😂😂🐒🐒🐒🐒🗑🗑🗑🗑🗑🗑💩💩💩💩💩
# 	 [regione] Sardegna  [geo] 39.97 8.68
#  	 [regione] Sicilia [geo] 37.46 15.03
# **************************************************
# Ma a me che mi frega di ciò che pensi di sapere e credi di nascondermi? Non nde cherio intendere. Mi nd'affutto dedde. Mi la cherer dare ti la ponzo issupra e s'altare ma non nde cherio intendere de inghirios de sa conca tua. Il menestrello continua a farronzanare cussu è su prob
# 	 [regione] Sardegna  [geo] 40.33 9.3
#  	 [regione] Lazio [geo] 41.89 12.54
# **************************************************
# Complimenti per la trasmissione, mancu sulu s'è votato (per i non terroni, nemmeno da solo si è votato) [URL]
# 	 [regione] Calabria  [geo] 39.27 16.27
#  	 [regione] Sicilia [geo] 37.46 15.03
# **************************************************
# Quando si semina, si raccoglie! Ed io…raccolgo, raccolgo… e risemino pure (a facc e chi c vo mal!)!!! #olive o#live @ [LOCATION] [URL]
# 	 [regione] Campania  [geo] 40.35 15.0
#  	 [regione] Campania [geo] 40.85 14.24
# **************************************************
# [USER] [USER] [USER] sempre. ce stanno du vecchietti a lavorà su sto cazzo de ponte co na cariola e du pale. un ponte dove transitano un numero impressionante de macchine
# 	 [regione] Lazio  [geo] 41.89 12.54
#  	 [regione] Lazio [geo] 41.89 12.54
# **************************************************
# [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] Ahhhh, qul lì l'era n'elenc ad gnugnu???? Anduma bin, tses propi n'amisa! 😝😝😝😝
# 	 [regione] Piemonte  [geo] 45.07 7.67
#  	 [regione] Sardegna [geo] 40.01 9.25
# **************************************************
# Mi piacerebbe che tutti quelli che fanno le pulci a pensieri e parole degli altri, stessero attenti a spartizioni, costi, assunzioni, bilanci, vitalizi, ed invece come sempre si ripete la storia della pagliuzza e la trave. Av salut burdel
# 	 [regione] Emilia Romagna  [geo] 44.48 11.33
#  	 [regione] Campania [geo] 40.85 14.24
# **************************************************
# [USER] Nce ponno arivà. So limitati dal 1900.
# 	 [regione] Lazio  [geo] 41.89 12.54
#  	 [regione] Lazio [geo] 41.89 12.54
# **************************************************
# [USER
#  	 [regione] Lazio [geo] 41.89 12.54
# **************************************************
# [USER] [USER] Mi sa proprio di sì. N’ze guarda!
# 	 [regione] Toscana  [geo] 43.44 11.9
#  	 [regione] Lazio [geo] 41.89 12.54
# **************************************************
# [USER] La stava prendendo ma Buffon glielo ha impedito...nun sfruculiamm anche quando non ce n'è motivo jamm
# 	 [regione] Campania  [geo] 40.9 14.48
#  	 [regione] Campania [geo] 40.85 14.24
# **************************************************
# Two days of hard working (and drinking)! Doi dis di bon lavôr (e bevi cun grinte cence fâ finte)! Due giornate di lavoro sodo (e sodo bere)! @ [LOCATION] [URL]
# 	 [regione] Friuli-Venezia Giulia  [geo] 46.16 13.19
#  	 [regione] Veneto [geo] 45.4 12.38
# **************************************************
# [USER] Che poi anche in città no xe mal. [URL]
# 	 [regione] Friuli-Venezia Giulia  [geo] 45.67 13.78
#  	 [regione] Veneto [geo] 45.4 12.38
# **************************************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[76], line 17
#      15 # inference
#      16 with torch.no_grad():
# ---> 17   gen_outputs = model.generate(
#      18     **tokenized_inputs,
#      19     return_dict_in_generate=True,
#      20     output_scores=True,
#      21     max_new_tokens=256, # how many token (wordpieces) to add to the input prompt. In ExtremITA answers are short
#      22     do_sample=False # we do not need any sampling or beam seach. We just need the "best" solution, so the greedy search is fine: https://huggingface.co/blog/how-to-generate
#      23   )
#      25   # decoding and printing
#      26   for i in range(len(gen_outputs[0])):
#
# File ~/.local/lib/python3.9/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/transformers/generation/utils.py:1736, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1728     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1729         input_ids=input_ids,
#    1730         expand_size=generation_config.num_return_sequences,
#    1731         is_encoder_decoder=self.config.is_encoder_decoder,
#    1732         **model_kwargs,
#    1733     )
#    1735     # 13. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 1736     result = self._sample(
#    1737         input_ids,
#    1738         logits_processor=prepared_logits_processor,
#    1739         logits_warper=prepared_logits_warper,
#    1740         stopping_criteria=prepared_stopping_criteria,
#    1741         generation_config=generation_config,
#    1742         synced_gpus=synced_gpus,
#    1743         streamer=streamer,
#    1744         **model_kwargs,
#    1745     )
#    1747 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    1748     # 11. prepare logits warper
#    1749     prepared_logits_warper = (
#    1750         self._get_logits_warper(generation_config) if generation_config.do_sample else None
#    1751     )
#
# File ~/.local/lib/python3.9/site-packages/transformers/generation/utils.py:2375, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    2372 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2374 # forward pass to get next token
# -> 2375 outputs = self(
#    2376     **model_inputs,
#    2377     return_dict=True,
#    2378     output_attentions=output_attentions,
#    2379     output_hidden_states=output_hidden_states,
#    2380 )
#    2382 if synced_gpus and this_peer_finished:
#    2383     continue  # don't waste resources running the code we don't need
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.9/site-packages/accelerate/hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File ~/.local/lib/python3.9/site-packages/transformers/models/llama/modeling_llama.py:1164, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1161 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1163 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1164 outputs = self.model(
#    1165     input_ids=input_ids,
#    1166     attention_mask=attention_mask,
#    1167     position_ids=position_ids,
#    1168     past_key_values=past_key_values,
#    1169     inputs_embeds=inputs_embeds,
#    1170     use_cache=use_cache,
#    1171     output_attentions=output_attentions,
#    1172     output_hidden_states=output_hidden_states,
#    1173     return_dict=return_dict,
#    1174     cache_position=cache_position,
#    1175 )
#    1177 hidden_states = outputs[0]
#    1178 if self.config.pretraining_tp > 1:
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.9/site-packages/accelerate/hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File ~/.local/lib/python3.9/site-packages/transformers/models/llama/modeling_llama.py:968, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     957     layer_outputs = self._gradient_checkpointing_func(
#     958         decoder_layer.__call__,
#     959         hidden_states,
#    (...)
#     965         cache_position,
#     966     )
#     967 else:
# --> 968     layer_outputs = decoder_layer(
#     969         hidden_states,
#     970         attention_mask=causal_mask,
#     971         position_ids=position_ids,
#     972         past_key_value=past_key_values,
#     973         output_attentions=output_attentions,
#     974         use_cache=use_cache,
#     975         cache_position=cache_position,
#     976     )
#     978 hidden_states = layer_outputs[0]
#     980 if use_cache:
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.9/site-packages/accelerate/hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File ~/.local/lib/python3.9/site-packages/transformers/models/llama/modeling_llama.py:713, in LlamaDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position)
#     710 hidden_states = self.input_layernorm(hidden_states)
#     712 # Self Attention
# --> 713 hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     714     hidden_states=hidden_states,
#     715     attention_mask=attention_mask,
#     716     position_ids=position_ids,
#     717     past_key_value=past_key_value,
#     718     output_attentions=output_attentions,
#     719     use_cache=use_cache,
#     720     cache_position=cache_position,
#     721 )
#     722 hidden_states = residual + hidden_states
#     724 # Fully Connected
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.9/site-packages/accelerate/hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File ~/.local/lib/python3.9/site-packages/transformers/models/llama/modeling_llama.py:661, in LlamaSdpaAttention.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position)
#     658 attn_output = attn_output.transpose(1, 2).contiguous()
#     659 attn_output = attn_output.view(bsz, q_len, self.hidden_size)
# --> 661 attn_output = self.o_proj(attn_output)
#     663 return attn_output, None, past_key_value
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1696, in Module.__getattr__(self, name)
#    1687         self._backward_pre_hooks = OrderedDict()
#    1689 # On the return type:
#    1690 # We choose to return `Any` in the `__getattr__` type signature instead of a more strict `Union[Tensor, Module]`.
#    1691 # This is done for better interop with various type checkers for the end users.
#    (...)
#    1694 # See full discussion on the problems with returning `Union` here
#    1695 # https://github.com/microsoft/pyright/issues/4213
# -> 1696 def __getattr__(self, name: str) -> Any:
#    1697     if '_parameters' in self.__dict__:
#    1698         _parameters = self.__dict__['_parameters']
#
# KeyboardInterrupt:
