# %% [markdown]
# <a href="https://colab.research.google.com/github/crux82/BISS-2024/blob/main/BISS-2024_LAB-2.3_ExtremITA_inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Camoscio VS Minerva LLMs comparison when finetuned on the GeoLingIt dataset

# %% [markdown]
# The tutorial is split into 4 steps, reflecting the aforementioned process:
# - Step 1 - Encoding the data
# - Step 2 - Training the LLaMA model
# - **Step 3 - Inference: generating answers**
# - Step 4 - Deconding the data

# %% [markdown]
# # Index:
# 1. Introduction, Workflow and Objectives
# 2. Preliminary steps
# 3. Loading the model
# 4. Generating answers
# 5. Saving the data in the 4-column format

# %%
# install eventually required packages

! pip3 install peft
! pip3 install sentencepiece
! pip3 install accelerate
! pip3 install bitsandbytes
! pip3 install geopy
! pip3 install scikit-learn
# Out:
# Requirement already satisfied: peft in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (0.10.0)
# Requirement already satisfied: numpy>=1.17 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from peft) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from peft) (23.2)
# Requirement already satisfied: psutil in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from peft) (5.9.6)
# Requirement already satisfied: pyyaml in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from peft) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from peft) (2.1.1)
# Requirement already satisfied: transformers in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from peft) (4.40.1)
# Requirement already satisfied: tqdm in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from peft) (4.64.0)
# Requirement already satisfied: accelerate>=0.21.0 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from peft) (0.27.2)
# Requirement already satisfied: safetensors in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from peft) (0.4.2)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from peft) (0.22.2)
# Requirement already satisfied: filelock in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft) (2023.10.0)
# Requirement already satisfied: requests in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft) (4.7.1)
# Requirement already satisfied: sympy in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.13.0->peft) (1.12)
# Requirement already satisfied: networkx in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.13.0->peft) (3.2.1)
# Requirement already satisfied: jinja2 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.13.0->peft) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.13.0->peft) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.13.0->peft) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.13.0->peft) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.13.0->peft) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.13.0->peft) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.13.0->peft) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft) (12.3.101)
# Requirement already satisfied: regex!=2019.12.17 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from transformers->peft) (2023.10.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from transformers->peft) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from jinja2->torch>=1.13.0->peft) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from sympy->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: sentencepiece in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (0.1.99)
# Requirement already satisfied: accelerate in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (0.27.2)
# Requirement already satisfied: numpy>=1.17 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from accelerate) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from accelerate) (5.9.6)
# Requirement already satisfied: pyyaml in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from accelerate) (2.1.1)
# Requirement already satisfied: huggingface-hub in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from accelerate) (0.22.2)
# Requirement already satisfied: safetensors>=0.3.1 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from accelerate) (0.4.2)
# Requirement already satisfied: filelock in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (4.7.1)
# Requirement already satisfied: sympy in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.3.101)
# Requirement already satisfied: requests in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from huggingface-hub->accelerate) (4.64.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: bitsandbytes in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (0.43.0)
# Requirement already satisfied: torch in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from bitsandbytes) (2.1.1)
# Requirement already satisfied: numpy in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from bitsandbytes) (1.26.0)
# Requirement already satisfied: filelock in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (3.13.1)
# Requirement already satisfied: typing-extensions in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (4.7.1)
# Requirement already satisfied: sympy in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (1.12)
# Requirement already satisfied: networkx in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (3.2.1)
# Requirement already satisfied: jinja2 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (3.1.2)
# Requirement already satisfied: fsspec in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from torch->bitsandbytes) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes) (12.3.101)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from jinja2->torch->bitsandbytes) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages (from sympy->torch->bitsandbytes) (1.3.0)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import pandas as pd

from peft import PeftModel
from transformers import LlamaTokenizer, LlamaForCausalLM, GenerationConfig
import re
from os import makedirs
from os.path import isdir
import csv
import math
import pprint
from tqdm import tqdm
from geopy.distance import geodesic
from sklearn.metrics import f1_score
import numpy as np

# %%
relPath = '.'
TASK = 'geolingit'

# %% [markdown]
# ## Encode the test set

# %%
def clean_input_text(text):
    text = re.sub(r'\t+', ' ', re.sub(r'\n+', ' ', re.sub(r'\s+', " ", text)))
    text = text.rstrip()
    return text

def encode():
    if not isdir(f"out/{TASK}"):
        makedirs(f"out/{TASK}")

    data = dict()

    with open(f"{relPath}/GeoLingIt/test_a_GOLD.tsv", encoding="utf-8") as f:
        reader = csv.DictReader(f, delimiter="\t", quoting=csv.QUOTE_NONE)
        for row in reader:
            text = clean_input_text(row['text'])
            label = row['region']
            data[row['id']] = {
                'text': text,
                'label': label,
            }

    with open(f"{relPath}/GeoLingIt/test_b_GOLD.tsv", encoding="utf-8") as f:
        reader = csv.DictReader(f, delimiter="\t", quoting=csv.QUOTE_NONE)
        for row in reader:
            latitude = math.floor(eval(row['latitude'])*100)/100.
            longitude = math.floor(eval(row['longitude'])*100)/100.
            data[row['id']]['latitude'] = latitude
            data[row['id']]['longitude'] = longitude

    with open(f"out/{TASK}/test.txt", "w", encoding="utf-8") as f_o:
        for id, features in data.items():
            f_o.write(f"{id}\t{TASK}\t{features['text']}\t[regione] {features['label']} [geo] {features['latitude']} {features['longitude']}\n")
            
encode()

# %% [markdown]
# ### Utils code for generating text in the ad hoc form for each task

# %%
def task_to_prompt(task: str):
    if task == "geolingit":
        return "Scrivi la regione di appartenenza di chi ha scritto questo testo, seguito dalla latitudine, seguita dalla longitudine."
    else:
        return "task sconosciuto"


 ################ GENERATE METHODS ################
def generate_prompt_pred(instruction, input_):
    return f"""Di seguito è riportata un'istruzione che descrive un task, insieme ad un input che fornisce un contesto più ampio. Scrivete una risposta che completi adeguatamente la richiesta.
### Istruzione:
{instruction}
### Input:
{input_}
### Risposta:"""

# %% [markdown]
# # Download the model
#
# This section provides detailed instructions on how to download and load the model. We specifically focus on the "Extremita" model, which has been trained and evaluated as part of a major competition. For more information on the competition and the model's performance, refer to the following link: https://ceur-ws.org/Vol-3473/paper13.pdf.
#
# The model is readily available on Hugging Face and consists of two main components: the original language model (Camoscio: ``sag-uniroma2/extremITA-Camoscio-7b``) and the adapters obtained through fine-tuning with all the data from Evalita 2023 in terms of adapters (``sag-uniroma2/extremITA-Camoscio-7b-adapters``).
#
# It is important to note that the model can be loaded using different precision levels, including 4-bit, 8-bit, and 16-bit approximations, as outlined below.

# %%
bits = "4" #@param [4, 8, "full"]

# %%
tokenizer = LlamaTokenizer.from_pretrained("yahma/llama-7b-hf")
tokenizer.padding_side = "left"
tokenizer.pad_token_id = (0)

# base model here, choose between 4, 8 bits or full precision
if bits == "8":
  model = LlamaForCausalLM.from_pretrained(
    "./LLaMinerva/checkpoint-426",
    load_in_8bit=True,
    torch_dtype=torch.float16,
    device_map="auto",
  )
elif bits == "4":
  model = LlamaForCausalLM.from_pretrained(
    "./LLaMinerva/checkpoint-426",
    load_in_4bit=True,
    torch_dtype=torch.float16,
    device_map="auto",
  )
else:
  model = LlamaForCausalLM.from_pretrained(
    "./LLaMinerva/checkpoint-426",
    torch_dtype=torch.float16,
    device_map="auto",
  )
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/39 [00:00<?, ?it/s]

# %%
model.config.pad_token_id = tokenizer.pad_token_id = 0
model.config.bos_token_id = tokenizer.bos_token_id = 1
model.config.eos_token_id = tokenizer.eos_token_id = 2

model.eval()
if torch.__version__ >= "2":
    model = torch.compile(model)

# %%
inputs = []
with open(f"{relPath}/out/{TASK}/test.txt", "r", encoding="utf-8") as f:
    for line in f.readlines():
        lc = re.split(r"\t|\[regione\]|\[geo\]", line)
        inputs.append(["1", TASK, lc[2], "[regione]" + lc[4] + " [geo]" + lc[5]])
    pprint.pp(inputs)
# Out:
# [['1',
#   'geolingit',
#   '#NapoliRijeka i cambi hanno fatto la differenza...anche se il gol di [USER] '
#   'è stato di cazzimma! Quello di [USER] con doppia cazzimma! Peccato per le '
#   "occasioni di #Petagna e #Insigne si poteva finire con un'imbarcata! "
#   '#ForzaNapoliSempre',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] E ti chiama Gugliermo Passeri di bar Armida e ti porta un’ape '
#   'du’ cami e tre purmi pieni di nuovi giocatori raccattati ni sudicio',
#   '[regione] Toscana  [geo] 43.78 11.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] In dialetto ti ghe rason...😉😁',
#   '[regione] Piemonte  [geo] 45.44 8.61\n'],
#  ['1',
#   'geolingit',
#   '[USER] Je c’è vo a cariola pe portalo a spasso',
#   '[regione] Lazio  [geo] 42.44 12.06\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Frastimo, ma no isco frastimare ca Deus non m’hat dadu su '
#   'destinu. Males cantas renas b’hat in mare e unzas cantu pesat su terrinu. '
#   'Su cannau ti tostet su Buzinu manzanu a carre lenta a t’impicare. Minutos '
#   'cantu zirat su rellozu ti dian issacadas de puntorzu',
#   '[regione] Sardegna  [geo] 40.07 8.74\n'],
#  ['1',
#   'geolingit',
#   "Certe vorte, ner silenzio della mi 'amera, vando tuitto 'on voi, sento i mi "
#   "vicini di 'asa 'e letiano (moglie e marito) su bischerate della madonna, e "
#   'penzo che ho fatto bene io a uni sposammi....☹',
#   '[regione] Toscana  [geo] 43.66 10.36\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Giorgina, ara che stasira ghe la partida, spiegati meglio o '
#   'tas de le....',
#   '[regione] Lombardia  [geo] 45.29 9.84\n'],
#  ['1',
#   'geolingit',
#   "[USER] Quannu 'a fazzu t'a fazzu vidire('a parmigiana è logicu😁)",
#   '[regione] Calabria  [geo] 39.1 17.1\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Se smissia co quea dei gavettoni ... sercavo riparo pae bosse '
#   'de vin dir el vero.. no voria mai che ... 😉',
#   '[regione] Veneto  [geo] 45.4 12.38\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ju ca sugnu cuttu ogni vota era na trageria... INFATTI MI FICI U '
#   'TELEPASS PI EVITARI MALI CUMPASSI...',
#   '[regione] Sicilia  [geo] 37.46 15.03\n'],
#  ['1',
#   'geolingit',
#   "Cazzo è tutto sudato per l'enorme lavoro da smaltire. Ci mette meno tempo a "
#   'tirar fuori quei pochi buoni, cioè mica a Crosetto ghe né miga, ovvio di '
#   'buoni. [URL]',
#   '[regione] Lombardia  [geo] 45.48 9.65\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] Sé qualchedun paga.. vegno anche mi. A che ora?',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.59 13.77\n'],
#  ['1',
#   'geolingit',
#   'Beh dai speruma an ben ed è qui che finisce il mio parlare e inizia il mio '
#   'zittire',
#   '[regione] Piemonte  [geo] 45.59 8.01\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] [USER] Quella è spettacolare over oltre style, ma che '
#   'ne sann😂😂😂. O gè over ce stamm facenn viecchie',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   'Heavy rainy Sunday... good wine, chill and study! Domenie di ploe...nus '
#   'reste dome un bon taj, la polse e il studiâ! Domenica di pioggia '
#   'incessante...un buon bicchiere, relax e studio! @ [LOCATION] [URL]',
#   '[regione] Friuli-Venezia Giulia  [geo] 46.16 13.19\n'],
#  ['1',
#   'geolingit',
#   '[USER] ciao Roby töta post? Dai gnaro ma racomande fago eder che ta set de '
#   'breso',
#   '[regione] Lombardia  [geo] 45.31 10.0\n'],
#  ['1',
#   'geolingit',
#   '[USER] 👏👏👏👏 Grande Felix , purtroppo in 🇮🇹 pensano di essere tutti '
#   'competenti,poi ( come tu dimostri) i fatti li smentiscono,eee che cazz di '
#   'paes è 🇮🇹, buona giornata Felix un abbraccio a te e alla mia Vasto,Lu Wast '
#   'è terr Dor 😉👍',
#   '[regione] Abruzzo  [geo] 42.21 14.4\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ti te se insognett de vess vestì d’angiul 😏',
#   '[regione] Lombardia  [geo] 46.0 8.74\n'],
#  ['1',
#   'geolingit',
#   '[USER] Semp na chiavc, ma senza mascherine',
#   '[regione] Campania  [geo] 40.81 14.06\n'],
#  ['1',
#   'geolingit',
#   '[USER] Méi del panetùn ghe n’é minga. Per le penne sono più democratico ...',
#   '[regione] Lombardia  [geo] 45.41 9.25\n'],
#  ['1',
#   'geolingit',
#   '[USER] m stai facenn girà e pall e l’uocchi... fa o brav',
#   '[regione] Campania  [geo] 40.88 14.12\n'],
#  ['1',
#   'geolingit',
#   'Oooooo ades ghi rot i coioni andate a vivere al trove se non volete '
#   'rispettare il 90 x 100 degli italiani vaccinati [URL]',
#   '[regione] Lombardia  [geo] 45.41 10.38\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Ghe ze vari tipi de spissa par quelo 😁😁😁',
#   '[regione] Veneto  [geo] 45.92 11.64\n'],
#  ['1',
#   'geolingit',
#   'Caro Mariga, noi asén che i pecoroi talici i core drio ae betole dea '
#   'teevision... Speren chel sciope sta scoazera de stato, che sie la olta bona '
#   '[URL]',
#   '[regione] Veneto  [geo] 46.04 11.86\n'],
#  ['1',
#   'geolingit',
#   "[USER] Adesso che è finita l'emergenza covid, nisciun vo' impadta e "
#   'casatiell... 😂😂😂',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   "Quando scrivono scopami il cuore, scopami il cervello, oppure l'anima.... "
#   'bah! Na passat rint a cucin no?',
#   '[regione] Campania  [geo] 40.74 14.56\n'],
#  ['1',
#   'geolingit',
#   "[USER] Giusta un po' di invidia. Famo pena, almeno lasciatece qualche "
#   "lumicino per gioire se no li poru [USER] entro l'anno se spara",
#   '[regione] Marche  [geo] 43.13 13.07\n'],
#  ['1',
#   'geolingit',
#   "Si come no, anzi l'estate verra' a Pasqua e ad Agosto festeggiamo il "
#   'Natale! Ma statt zitt ché meglio! [URL] [URL]',
#   '[regione] Campania  [geo] 41.05 14.33\n'],
#  ['1',
#   'geolingit',
#   '[USER] La roba che fa vegni el nervus l è che nisun sa se voer di '
#   "comunista, adopren la parola duma per far stremi' la gent ignurant.",
#   '[regione] Lombardia  [geo] 45.53 9.28\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Secondo me invece sta pensand... Aee e che guaio che agg '
#   'fatt... E mo quand ma dà nata vot...',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   "[USER] Da gay ti dico che ste frocie sfrante me stanno sur cazzo, c'ha na "
#   'cattiveria ncorpo che se lo ncolla...insopportabile.',
#   '[regione] Lazio  [geo] 41.49 12.59\n'],
#  ['1',
#   'geolingit',
#   "Comunque #Djokovic è n'omm che pall! Al di là se si è d'accordo con quello "
#   'che pensa e dice Djokovic ritiene che aver proibito a russi e bielorussi di '
#   'partecipare al prestigioso appuntamento sull’erba sia stato ingiusto [URL]',
#   '[regione] Campania  [geo] 40.74 14.56\n'],
#  ['1',
#   'geolingit',
#   'ARBITRO, SI NA CHIAVICA E PURE NA LOTA... 🤨🤨🤨🤨',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ocio che doman te ghe da votàr, Andrea!',
#   '[regione] Veneto  [geo] 45.26 11.11\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Per magnar da soeo posso star casa 😂😂',
#   '[regione] Veneto  [geo] 45.4 12.38\n'],
#  ['1',
#   'geolingit',
#   "Quelli che non passano lo straccio ma DANNO 'R CENCIO. Quelli che a carte "
#   "gioano cor REGIO e ir GOBBO. Quelli che CE N'HO UN FOTTIO, che È DIACCIO "
#   'MARMATO, che ir primo giorno di mare pigliano la FOATA. Quelli che mangiano '
#   "a UFFO, che ti diano LEVATI DI 'ULO. ....continua",
#   '[regione] Toscana  [geo] 43.5 10.15\n'],
#  ['1',
#   'geolingit',
#   '[USER] Bisognerebbe saperli materializzare .... !! Ma ovviamente .. belin '
#   ".... NO SE PEU SCIUSCIA' E SCIORBI'",
#   '[regione] Liguria  [geo] 44.51 9.25\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] viecce a trovà che se famo na carbonara',
#   '[regione] Lazio  [geo] 41.88 12.22\n'],
#  ['1',
#   'geolingit',
#   '[USER] Minchia, quantu muommi. 😅',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   '[USER] Immoi giai🔴🔵🔴🔵🔴🔵🔴🔵',
#   '[regione] Sardegna  [geo] 39.97 9.65\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Te vojo coregge solo na cosa, biardo cò na “i” sola',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "[USER] Cess funti oghinno commo, dos'abbrugiada. E cust'annada puru è fatta",
#   '[regione] Sardegna  [geo] 40.01 9.25\n'],
#  ['1',
#   'geolingit',
#   '[USER] A no tu che ritt na strunzat ma noi che abbiamo travisato? Quindi ti '
#   'dobbiamo pure chiedere scusa. Agg pacienz faciv cchiù bella figura si t '
#   'stiv zitt.',
#   '[regione] Campania  [geo] 40.84 14.1\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Se e quann o vir io sto aspettando ancora una cosa.... Non '
#   'pensare a male però chiariamo 😁',
#   '[regione] Campania  [geo] 40.22 15.03\n'],
#  ['1',
#   'geolingit',
#   '[USER] Cioè uno prova ad acquistare i biglietti, si mette in fila, poi '
#   'arriva il suo turno e si deve vedere fermato perché ci vuole la tessera del '
#   'tifoso? Nel giorno in cui è aperta la vendita LIBERA! Ma tutt appost?! Ch è '
#   'diventat nu privè o stadio? Ch scuorn ca sit',
#   '[regione] Campania  [geo] 40.92 14.12\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Ma su IG tutti a pijalla pel culo ho visto tipo 10 stories de '
#   'seguito, onestamente la tavola era bella proprio, giocosa eppure natalizia, '
#   "poi lei resta la stronza da pija' a sberle che tutti sappiamo",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'E ma tu sei un altro che deve prendere il tuo posto. Dedde, semper deo soe '
#   "poi batta unu farrazzone chi colata a goi pessande non d'isco itte. Ma "
#   "tantu torrammusu a dommo e pezzi deo abbarro ch'in su traballu meu. Deo soe "
#   'rizzu non riccu. Ca incue ba pezzi immaginazione.',
#   '[regione] Sardegna  [geo] 40.33 9.3\n'],
#  ['1',
#   'geolingit',
#   "[USER] Ma ancora? Qui nel pomeriggio il cielo si è aperto. A gh'e' un fredd "
#   "da l'ostia ma l'è sutt",
#   '[regione] Emilia Romagna  [geo] 44.69 10.63\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] No. Chista na sacciu manco ieu 😂',
#   '[regione] Puglia  [geo] 40.41 18.18\n'],
#  ['1',
#   'geolingit',
#   '[USER] Stupido e anche omofobo, ebbi a discutere tempo fa, bloccato stu '
#   'trmon 😉',
#   '[regione] Puglia  [geo] 40.86 16.84\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Macché, è che avevo una risposta acidissima, ma non mi sembra '
#   'corretto inquinare il profilo di Antonio. 😂 Comunque si, doi pataf non gli '
#   'avrebbero fatto male...',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.95 12.97\n'],
#  ['1',
#   'geolingit',
#   '[USER] Va ben cussi Luisa, anca massa, se fusse Ti no me preoccuparia '
#   'proprio! E se qualchedun rompe i Cojoni, mandeo a cagar! Ansi, Ghe penso mi '
#   '! 🚀💤💣💥🔥',
#   '[regione] Veneto  [geo] 45.56 12.26\n'],
#  ['1',
#   'geolingit',
#   "Compa', ve vojo bene, ma la rivoluzione d'ottobre con Gualtieri non se pò "
#   "senti' 🙄 [URL]",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'Go el ghe sboro fassìe',
#   '[regione] Veneto  [geo] 45.45 12.53\n'],
#  ['1',
#   'geolingit',
#   "[USER] Domani l'amica di mia nipote farà il tampone, da privati...credo che "
#   "mercoledì sapremo qualcosa. Se l'ha scansato stamm appost, sennò dovranno "
#   'farlo anche le mie nipoti',
#   '[regione] Campania  [geo] 40.9 14.48\n'],
#  ['1',
#   'geolingit',
#   "[USER] 🤣🤣🤣 una tassa de inu nieddu e t'arrellassasa prusu de un'ora de yoga",
#   '[regione] Sardegna  [geo] 39.78 9.12\n'],
#  ['1',
#   'geolingit',
#   '[USER] Noe... Tocca resiste fino a domani almeno... Però oggi ce poi mette '
#   "l'ovo sodo, quillo sie. 😁",
#   '[regione] Umbria  [geo] 43.13 12.36\n'],
#  ['1',
#   'geolingit',
#   "[USER] Sput' n facce.... Mejo n'azione diretta",
#   '[regione] Lazio  [geo] 42.1 12.52\n'],
#  ['1',
#   'geolingit',
#   '[USER] Can del porco go pensá, go da romparme el cueo par chealtri quando '
#   "che podarìa romparmelo pa 'me fameja e niente da fare. I' ndará vanti come "
#   'mussi finché i tien bota, finché no i trova do strozzini chel compra. Me '
#   'dispiase tantissimo ma i ga deciso così. Un abbraccio.',
#   '[regione] Veneto  [geo] 45.4 11.56\n'],
#  ['1',
#   'geolingit',
#   '[USER] Hai ragione ce vo na marenn salsicce e fiariell e mi bell bicchier e '
#   'con russo😜😜😜😜 [URL]',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   "[USER] Che una #prescritta faccia la morale a chi ha vinto, l'è al mond "
#   "ch'al va a l'arversa... altar quel, contra la #Juve i t'ha dà 7 rigur a "
#   'favore, par quest, at devi taser!!!!',
#   '[regione] Emilia Romagna  [geo] 44.8 11.67\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] anvedi che mi hai ricordato. Quella fu na vera bolgia',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "[USER] Ne che gnente gnente questa se' sta a monta' mpo'la capoccia?",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] che du cojoni co sta storia. mentono sapendo di mentire',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] ca c sta r’asci pazz!!!!',
#   '[regione] Campania  [geo] 40.81 14.34\n'],
#  ['1',
#   'geolingit',
#   'En ne pos più… (@ [LOCATION] [URL]',
#   '[regione] Marche  [geo] 43.81 13.01\n'],
#  ['1',
#   'geolingit',
#   'Ma cu è a picciridda chiù beddha ro munnu? ♥️ #Sorellepersempre #Rai1',
#   '[regione] Sicilia  [geo] 36.87 14.82\n'],
#  ['1',
#   'geolingit',
#   'Il massimo...ghe ne minga par nisun @ [LOCATION] [URL]',
#   '[regione] Piemonte  [geo] 45.75 8.54\n'],
#  ['1',
#   'geolingit',
#   "Semo passati dal Surf agli Sci n'attimo proprio",
#   '[regione] Lazio  [geo] 41.88 12.22\n'],
#  ['1',
#   'geolingit',
#   '[USER] Aspettamo lunedì pe ride',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'Se non chiudiamo Twitter scumpar o Napoli. Ma foss infetto stu social? '
#   '[URL]',
#   '[regione] Campania  [geo] 40.9 14.3\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] [USER] Ma quanno er Barone faceva fa'gli allenamenti per i "
#   'cross per ore ed ore ce sarà stato un motivo o no ? Ma Caldstrop un cross, '
#   "dico uno, lo voi indovina '? Non dico come Begamp ma almeno come "
#   'Rocca,Nela, Chierico..........cazzarola.....',
#   '[regione] Lazio  [geo] 42.0 12.63\n'],
#  ['1',
#   'geolingit',
#   "[USER] Mi fatto pijà 'n córpo... Manco pe' scherzo...",
#   '[regione] Marche  [geo] 43.32 12.91\n'],
#  ['1',
#   'geolingit',
#   "[USER] Dai fa l'brau anca ti, l è duma' culpa del poc temp per la "
#   "sperimentasiun se ghe' un pu' de cunfusiun. I sciensia han dou' tira' foera "
#   "un vacin in dudes mes per salva' el cu' a la gent",
#   '[regione] Lombardia  [geo] 45.64 9.47\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] …sono un po’ in ritardo mi sa. …ma iammessi bènnia deu puru a '
#   'sa birrandara…',
#   '[regione] Sardegna  [geo] 39.14 8.96\n'],
#  ['1',
#   'geolingit',
#   '[USER] Alla prossima , dite che le bare le han spedite con gli scud. Fa più '
#   'effetto. Ma ande bein a cagher valà.',
#   '[regione] Emilia Romagna  [geo] 44.58 10.85\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ma famme capì te sogni er Prof anche di notte? Gnente gnente stai a '
#   'rosicà?',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] Bela tusa, quand te parler meneghin '
#   '🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f, te basaria i '
#   'pe’ 😜',
#   '[regione] Lombardia  [geo] 45.46 9.15\n'],
#  ['1',
#   'geolingit',
#   "[USER] Allegri ,sembra il ciuccio di zio Camillo. Tutt o'vvon e nosciun "
#   "so'pigl.",
#   '[regione] Campania  [geo] 40.68 14.53\n'],
#  ['1',
#   'geolingit',
#   'Semo nati pe soffri’ 😓 [URL]',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] Mia madre all\'annuncio sella mia prima cattedra ebbe a dirmi:" miga '
#   't\'ho faitu studiaa pe-e ninte!"',
#   '[regione] Liguria  [geo] 44.44 8.88\n'],
#  ['1',
#   'geolingit',
#   '[USER] Mejo na punturina de acido ialuronico e pe 6 mesi stai apposto🤪',
#   '[regione] Lazio  [geo] 41.49 12.59\n'],
#  ['1',
#   'geolingit',
#   '[USER] .... orpo! Così giovane?!? Io mi sono reso conto che, invecchiando, '
#   "sono diventato intollerante, soprattutto verso l'imbecillità ottusa ed "
#   "arrogante... e sono convinto che l'intolleranza sia una cifra della "
#   'saggezza....',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.94 13.59\n'],
#  ['1',
#   'geolingit',
#   '[USER] "Ma si nat in Italy...sient a me nun c\' sta nient a fa" 🤣',
#   '[regione] Campania  [geo] 40.71 14.59\n'],
#  ['1',
#   'geolingit',
#   '[USER] Nun sacciu chi cazzu pinsari',
#   '[regione] Sicilia  [geo] 36.73 14.85\n'],
#  ['1',
#   'geolingit',
#   'Questa ci mancava, 500 posti letto Covid in struttura vecchia e non sicura. '
#   "Suma propi bin ciapa' [URL]",
#   '[regione] Piemonte  [geo] 45.07 7.67\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ma l’anima delli mejo mortacci vostra e de chi ve vota',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Se gà za dimostrà magnanimo na volta trasformando acqua in '
#   'vin',
#   '[regione] Veneto  [geo] 45.4 12.38\n'],
#  ['1',
#   'geolingit',
#   'Qua no iera pi posto bon da piazzar qualcun so na carega. Qua i iera drio '
#   'deventar poareti e cattivi. E povertà e cattiveria xe do brutte bestie '
#   'combinae insieme.',
#   '[regione] Veneto  [geo] 45.18 11.48\n'],
#  ['1',
#   'geolingit',
#   '[USER] Prima ha parlato De Magistris chill at criatur viziato "Le mie '
#   'ordinanze sono una provocazione!" 🤦😣😣😣😣😣😣 Comincia il botta e risposta '
#   "telematico Ngia' facimm cchiu! 😭😭😭😭😭😭😭",
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ocio che se sbrissa!',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.61 13.86\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] [USER] [USER] N\'è che posso dije a coso "aspe che '
#   'scrivo su Twitter che sto a scopà". Me pare scortese.',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] Comunque me candiderei pur’io pe na medajetta eh',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] o Alvaro...prova a bogai cussu cazz’e scritta jugador del [USER] po '
#   'pragheri e zacca [USER] 😜😜😜😜',
#   '[regione] Sardegna  [geo] 39.97 8.68\n'],
#  ['1',
#   'geolingit',
#   'Niente asfalto, solo campagna e sentieri del Cremasco, fino...alla Rocca di '
#   'Soncino (CR)!!! Trop bèl bagai 💪💪🚵🚵😍 [URL]',
#   '[regione] Lombardia  [geo] 45.4 9.85\n'],
#  ['1',
#   'geolingit',
#   'Se i stupidi gavesse e foje, sarissimo tuti ae’ombria.',
#   '[regione] Veneto  [geo] 45.46 12.5\n'],
#  ['1',
#   'geolingit',
#   "[USER] Mamma mia.. le fatt na' mappina.. 😂😂😂",
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   "[USER] Che poi a me la tuta piace na cifra da vede. Subisco un po' lo "
#   'stigma sociale che noi con la fregna dovemo stà sempre apposto.',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'El metes adrè, anche qui a Piacenza di dice mëts a drè, letteralmente '
#   '"mettersi dietro a fare", cioè tra il dire e il fare bisogna intanto '
#   'cominciare (a fare) 😄 [USER] #propagadalive',
#   '[regione] Emilia Romagna  [geo] 45.05 9.71\n'],
#  ['1',
#   'geolingit',
#   'Ma no ve passa gnanca par sbaglio idea chel se sia rotto I cojoni ? Capita '
#   'oh ... #CR7',
#   '[regione] Veneto  [geo] 45.4 12.38\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ha una gran bella voce, ed è diversa dalle altre. Potrebbe '
#   'raccogliere consensi. La cantante Azera me piass minga. #Eurovision #ESCita',
#   '[regione] Lombardia  [geo] 45.62 9.32\n'],
#  ['1',
#   'geolingit',
#   '[USER] Boni! Pure tu non sei annato male! 😂🤣😂👏💪🟡🔴',
#   '[regione] Lazio  [geo] 42.44 12.06\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] E a maron co manten allert a sta lot',
#   '[regione] Campania  [geo] 41.23 13.87\n'],
#  ['1',
#   'geolingit',
#   'Non sopporto De Luca, ma su sto fatto che non ha risposto al telefono a '
#   'Massimo Giletti... ha fatt bbuon! Non è che uno deve rispondere a tutt e '
#   'sciem ca chiammane',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   "[USER] È n'iperbole, pe rende mejo er concetto. Qui de usano figure "
#   "retoriche, t'aricordo che so na donna de curtura. Perle ai porci. Tze!",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] Pe apprezzare l'ipersapido pecorino serve avecce il dna "
#   'capitolino. (Ho fatto la rima)',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "Si a vint'ann' ero nu strunz', ora song' nu Dio e strunz'! ✊😋😝💪👌😍🖕 [URL]",
#   '[regione] Campania  [geo] 40.9 14.3\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ottimo Fora di bal',
#   '[regione] Piemonte  [geo] 44.91 8.64\n'],
#  ['1',
#   'geolingit',
#   'La mia vita da 2 anni un’eterna sala d’attesa per le malattie immaginarie '
#   'di mio padre, tocca se nde pigghia mai lu covid, siamu immuni di razza🙄 '
#   '[URL]',
#   '[regione] Puglia  [geo] 40.04 18.01\n'],
#  ['1',
#   'geolingit',
#   '[USER] O capì o capì; adess la Pula la diss n’casso, ma n’cumpensu… la '
#   'giuega le, e…. La perdi’ anca i ball! Te saludi, stami ben…',
#   '[regione] Lombardia  [geo] 45.58 8.94\n'],
#  ['1',
#   'geolingit',
#   "Da noi in Calabbria 'u vaccinu nu vivimu comu l'ovu sbattutu ccu ru marsala "
#   'Altro che #MioCuginoNews Siamo più forti delle fake news!😌😂😂😂😂😂',
#   '[regione] Calabria  [geo] 39.1 17.1\n'],
#  ['1',
#   'geolingit',
#   '[USER] RIGGITANO I MERDA, E CHI MI TI PIGGHIA NA BOTTA I SCIORTA CA TA FAI '
#   '3 JORNA NTO CESSU, NSIVATU',
#   '[regione] Calabria  [geo] 38.1 15.74\n'],
#  ['1',
#   'geolingit',
#   '[USER] 😂 “dumà i vacc g’han l’anel al nas”, poteva andarti peggio',
#   '[regione] Lombardia  [geo] 46.0 8.74\n'],
#  ['1',
#   'geolingit',
#   '[USER] Tutta la Sicilia mancia arancini, sulu vui siti stotti ❤️',
#   '[regione] Sicilia  [geo] 38.17 15.53\n'],
#  ['1',
#   'geolingit',
#   "[USER] M'issi nfucata n'anca.... Lezione di #salentino parte 2 🤣🤣🤣🤣🤣🤣",
#   '[regione] Puglia  [geo] 40.41 18.18\n'],
#  ['1',
#   'geolingit',
#   'Senza muzzicari u cannolu un poi sapiri sa ricotta è fitusa. @ [LOCATION] '
#   '[URL]',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   '[USER] Il Campari se unnè diaccio marmato e un sa d’una sega! Piglierai un '
#   'bianchino?',
#   '[regione] Toscana  [geo] 43.44 11.9\n'],
#  ['1',
#   'geolingit',
#   "[USER] Guaglio' Buongiorno! Azz! Vir te si scurdat puparuol e mulignane "
#   "pero '!! E che se fa😑 [URL]",
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] E xè tutto un no se pol ciò 😂',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.67 13.78\n'],
#  ['1',
#   'geolingit',
#   '"Se fossi dalla vostra parte...", "Gli antagonisti". Ecco, viecce dalla '
#   'nostra parte! Te famo un culo come na cesta. #contebuffone',
#   '[regione] Toscana  [geo] 43.78 11.24\n'],
#  ['1',
#   'geolingit',
#   "[USER] Vista dal vivo all'Olimpico n'artro po infarto 😍",
#   '[regione] Lazio  [geo] 41.49 12.59\n'],
#  ['1',
#   'geolingit',
#   '[USER] A pigliat pur a bullett stu scurnacchiat',
#   '[regione] Campania  [geo] 40.81 14.06\n'],
#  ['1',
#   'geolingit',
#   '[USER] Che sguardo acuto e intelligente! Me senti ben e serèna a vedèl '
#   'inscì.',
#   '[regione] Lombardia  [geo] 45.46 9.15\n'],
#  ['1',
#   'geolingit',
#   '[USER] A mio marito è partito il Karaoke a tenore baroniese 😂😂😂 du lasso in '
#   'noe',
#   '[regione] Sardegna  [geo] 40.54 9.7\n'],
#  ['1',
#   'geolingit',
#   '[USER] Vorrei aggiungere una perla di speranza " pioe e c\'è lu sole, se '
#   'maritano le lucciole.',
#   '[regione] Marche  [geo] 43.36 13.43\n'],
#  ['1',
#   'geolingit',
#   '[USER] Fa semp chest sta lota. Che cazz sta a fa miez o camp',
#   '[regione] Campania  [geo] 41.08 14.35\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] esatto. un burlone che vo mette un po de benza sul '
#   'fuoco. ma noi semo boni de core e se famo li cazzi nostra',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] Ecco, quello che stavo giust’appunto osservando 😉 Ma '
#   'l’è bel anca inscì.',
#   '[regione] Lombardia  [geo] 46.0 8.74\n'],
#  ['1',
#   'geolingit',
#   '[USER] Per lavarte i cavei?',
#   '[regione] Veneto  [geo] 45.75 12.85\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Riri riri che a mamma a fatto i gnocchi. Monega di biga.',
#   '[regione] Friuli-Venezia Giulia  [geo] 46.25 13.35\n'],
#  ['1',
#   'geolingit',
#   '[USER] Vero è, ma semu senza picciuli',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   '[USER] fortuna che ghe xe anca ea peicoea, perché de ‘sti tempi de legno se '
#   'ne vede poco',
#   '[regione] Veneto  [geo] 45.24 12.03\n'],
#  ['1',
#   'geolingit',
#   '" A cap nu serv" per non aver fatto nulla ahahahhha, mamma mia e comm stamm '
#   'accis [URL]',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] A'..fraca' e datte na' svejata la vita è tutta un gioco anche "
#   "se c'è chi non si diverte 😁",
#   '[regione] Lazio  [geo] 41.95 12.93\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] E certo gli incompetenti sono al governo, e meno male, nelle '
#   'mani della destra saremmo tutti sotto terra, e biata attia in calabrese, '
#   'comunque li stanno arrestando tutti, mò aspetto a Salvini 🤣🤣',
#   '[regione] Calabria  [geo] 39.27 16.27\n'],
#  ['1',
#   'geolingit',
#   "[USER] Ho un amico che suona il trombone nella banda dell'Impruneta. Non "
#   "sarà che qualche nota 'e gliè andata un po' alta?",
#   '[regione] Toscana  [geo] 43.78 11.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] allora li vedemo tra du mesi',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "[USER] No, era na vecchia del palazzo mio. Che tra l'altro abita ai piani "
#   "alti, so entrata prima nel portone e l'ho pure fatta passà avanti per darle "
#   "la precedenza sull'ascensore. Li mortacci mia.",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "[USER] Sono i più belli. Qunn ce vo ce vo, t'esc aint all'anima ;)",
#   '[regione] Lazio  [geo] 41.23 13.53\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ovvio! Finisce 1-1 Gol di Marek e di Piotr e non si piglia collera '
#   'nisciun😉',
#   '[regione] Campania  [geo] 40.22 15.03\n'],
#  ['1',
#   'geolingit',
#   '~Ma se ghe penso alôa mi veddo o mà~💙 posto del cuore [URL]',
#   '[regione] Liguria  [geo] 44.05 9.82\n'],
#  ['1',
#   'geolingit',
#   "'Mancu si chiama u capu e Borgia po trasira' 🤥🤥🤥",
#   '[regione] Calabria  [geo] 38.89 16.61\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] No go mai avudo i cavei tanto longhi...',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.59 13.77\n'],
#  ['1',
#   'geolingit',
#   '[USER] E non la deve vedere. E ci mancherebbe. Annamo bbene annamo.',
#   '[regione] Lazio  [geo] 41.85 12.78\n'],
#  ['1',
#   'geolingit',
#   'io credevo che IL PICIO SCHERZASSE SULLO SPEGNERE I CONDIZIONATORI INVECE '
#   'LO HA FATTO PROPRIO IL PICIO',
#   '[regione] Piemonte  [geo] 45.04 7.77\n'],
#  ['1',
#   'geolingit',
#   'Tutti gia a rompe il cazzo per il caldo che so du giorni che fa caldo ... '
#   "io tutto sto caldo non lo sento anche perché all'ombra fa freddo, tra "
#   "l'altro questo è il periodo che t'incula nfatti sto raffreddato perso e co "
#   'la tosse, perché vivo al mare.',
#   '[regione] Lazio  [geo] 41.49 12.59\n'],
#  ['1',
#   'geolingit',
#   'Stasera cucino io, frittatona cipolla, peperone e pommodoro...riso indiano, '
#   'perfetto...Cannavacciuolo mi fà na pippa...Boia dè 🤪🤪🤪🤪🤪🤪🤪 @ [LOCATION] '
#   '[URL]',
#   '[regione] Toscana  [geo] 43.36 11.21\n'],
#  ['1',
#   'geolingit',
#   "[USER] Figgh'i pù [USER]",
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   '[USER] Non credo, ormai tutti sanno che è solo un ciaparat.',
#   '[regione] Piemonte  [geo] 45.05 7.59\n'],
#  ['1',
#   'geolingit',
#   'E mi dovaria credarghe che fasea tutto el Nonno e chealtri se portava casa '
#   'stipendio sensa far gnente. Certamente [URL]',
#   '[regione] Veneto  [geo] 45.6 11.58\n'],
#  ['1',
#   'geolingit',
#   '[USER] Statuto: se sei fregno entri, sennò aspetti. Scherzo. Il gruppo è la '
#   'community dove si condividono capacità (o skills) sociali, commerciali e un '
#   "po' tutte. Ci sono due messaggi che spiegano l'ingarbugliato piano per "
#   'evolvere il mondo senza disturbare troppo. Jo! ✌️😎',
#   '[regione] Abruzzo  [geo] 42.38 13.41\n'],
#  ['1',
#   'geolingit',
#   "[USER] Pe chi nu n'œ, ghe n'è de lungu. Necessita di traduzione?",
#   '[regione] Liguria  [geo] 44.4 8.62\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Je tiro na ciavatta',
#   '[regione] Lazio  [geo] 41.79 12.61\n'],
#  ['1',
#   'geolingit',
#   'ANNO NUOVO, NUOVE TASSE😂!!! Ma queste xe quee che te mete de buon umore '
#   'acomlagnando ea tua bibita preferita! Cossa ghe bevarissito ? @ [LOCATION] '
#   '[URL]',
#   '[regione] Veneto  [geo] 45.71 11.84\n'],
#  ['1',
#   'geolingit',
#   "Ma và stricati 'na mulinciana aru mussu E camina subb'i spin'i d'i rizzi "
#   'marini [URL]',
#   '[regione] Calabria  [geo] 39.1 17.1\n'],
#  ['1',
#   'geolingit',
#   'Raga, oggi sono andato alla Pamme, ho preso una birra (1,47 euro) , poi '
#   "vado alla 'assa a pagá, e quando piglio 'r portafoglio, vedo 'n terra du "
#   "euro....e gnente, l'ho pigliati, ho pagato, e m'hanno dato anco 'r "
#   'resto...😂😁',
#   '[regione] Toscana  [geo] 43.66 10.36\n'],
#  ['1',
#   'geolingit',
#   'IJ T’A FACESS NA FACC E PACC’R MA NON PERCHÉ SEI ETERO.. PERCHÉ PARLI!! '
#   'Anzi, prima ca a te a facess a chi t’è vutat!! [URL]',
#   '[regione] Campania  [geo] 40.78 14.73\n'],
#  ['1',
#   'geolingit',
#   'Giulio Cesare je fa na pippa a du mani [URL]',
#   '[regione] Lazio  [geo] 41.88 12.22\n'],
#  ['1',
#   'geolingit',
#   'Nn sto a piagne nn sto a piagne. E sopratutto nn me sto affezionà a sto '
#   'regazzino, pe’ niente proprio... [URL]',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'Na teglia de pasta ar forno Senti che poesia',
#   '[regione] Lazio  [geo] 41.88 12.22\n'],
#  ['1',
#   'geolingit',
#   '[USER] Si ma basta con le canzoni che te devi concentrà! Cantete bbone nghi '
#   'ssa vocc!',
#   '[regione] Abruzzo  [geo] 42.33 14.37\n'],
#  ['1',
#   'geolingit',
#   'E tui, fill’e chini sesi?” Seu filla de Sardigna! Bona Die a tottus! '
#   '#FéminasDeSardigna [URL]',
#   '[regione] Sardegna  [geo] 39.22 9.09\n'],
#  ['1',
#   'geolingit',
#   '[USER] Macché, se guarda en film de gueRa',
#   '[regione] Trentino-Alto Adige  [geo] 45.88 10.81\n'],
#  ['1',
#   'geolingit',
#   'Boia raga, vado dar dentista, ti ci trovo una topina..😳😳😳..poi vando mi '
#   'faceva la puilzia der tartaro, mi metteva le bocce addosso e mi diceva '
#   '"tutto bene?" Deh, è come voi sta, male?..un sentivo nulla... Raga, viva la '
#   'topa!',
#   '[regione] Toscana  [geo] 43.66 10.36\n'],
#  ['1',
#   'geolingit',
#   '[USER] Siii.... mo aggia sent pur è sciem!',
#   '[regione] Campania  [geo] 40.12 15.44\n'],
#  ['1',
#   'geolingit',
#   '[USER] 🤣🤣🤣🤣🤣🤣 je stamo tutti a scrive poesie di amore',
#   '[regione] Lazio  [geo] 41.88 12.22\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Ahahah la Frica dalle mie parti vuol dire bambina in dialetto '
#   '😆',
#   '[regione] Marche  [geo] 42.92 13.87\n'],
#  ['1',
#   'geolingit',
#   '[USER] A dormer ? Adess no ne!! Oooh bela la notte è lunga! Era per dire😉😉',
#   '[regione] Lombardia  [geo] 45.77 10.33\n'],
#  ['1',
#   'geolingit',
#   'Dai dai che esce! Dai dai! Fer brisa l’esen! 😂🌞 Ocio che domani, forse, '
#   'faccio un “percorso nuovo”. Fuori zona... 🥸 @ [LOCATION] [URL]',
#   '[regione] Emilia Romagna  [geo] 44.66 11.19\n'],
#  ['1',
#   'geolingit',
#   "[USER] Cussu, non è buono più, buttatelo nell'umido",
#   '[regione] Abruzzo  [geo] 42.45 14.2\n'],
#  ['1',
#   'geolingit',
#   'Pietro si tutt scem parli così con nonschalance davanti alle telecamere '
#   '#TemptationIsland',
#   '[regione] Campania  [geo] 40.93 14.44\n'],
#  ['1',
#   'geolingit',
#   '[USER] La socera era più sveja de lei',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'comunqueeeeeee [USER] riferisci al tuo amico che è chiu tuost ro pan tuost '
#   'p fa e purpett grazie ily❤️',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Andara beni qusa puru, sa sibula esti ottima',
#   '[regione] Sardegna  [geo] 39.19 8.41\n'],
#  ['1',
#   'geolingit',
#   "A fasse li cazzi propri n'se sbaja mai.",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] T’ho visto poco fa sul palco. T’eri inguardabile nel cercare di '
#   'imitare i rocker italiani degl’anni 80’.',
#   '[regione] Toscana  [geo] 43.79 11.02\n'],
#  ['1',
#   'geolingit',
#   "[USER] Miscell va a ciapa' di ratt è già stato detto?",
#   '[regione] Emilia Romagna  [geo] 44.69 10.63\n'],
#  ['1',
#   'geolingit',
#   'Adinolfi, Pillon e omofobi vari non attaccateve ar cazzo...... Buttateve ar '
#   'fiume, armeno farete felici le pantegane... [URL]',
#   '[regione] Lazio  [geo] 42.1 12.52\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Stasera 5 dietro fila come ho aggiunto. Per me c’era un cinno '
#   'che si divertiva a spingere il pulsante. Avrà preso due smatafloni spero 😆',
#   '[regione] Emilia Romagna  [geo] 44.48 11.33\n'],
#  ['1',
#   'geolingit',
#   'Ahahahahahahahahahahahah Chist è tutt scem... È a uallr e #Maradona '
#   '#ForzaNapoliSempre [URL]',
#   '[regione] Campania  [geo] 40.83 14.47\n'],
#  ['1',
#   'geolingit',
#   "[USER] Bisogna avecce er profilo de marmo pe' utilizzà st'argomento tra i "
#   'tanti disponibili...',
#   '[regione] Lazio  [geo] 41.76 12.63\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Agg fatt na bella Besciamella oggi, chissà se gli aggrada, '
#   'gliela porto domani per pranzo. [URL]',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   "Fa' chiù miracule 'na votte e vin ca 'na chiesa 'e santi!",
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] Perché Nun ve fate na vita e soprattutto li cazzi vostri. Avete na '
#   'squadretta, tifate quella e Nun rompetece li cojoni',
#   '[regione] Lazio  [geo] 41.88 12.22\n'],
#  ['1',
#   'geolingit',
#   "Me paro n'eroinomane a che ha svaligiato na farmacia.",
#   '[regione] Lazio  [geo] 41.63 13.32\n'],
#  ['1',
#   'geolingit',
#   "[USER] Ma va a ciapa' di ratt, va a trida' al giass in Russia!",
#   '[regione] Lombardia  [geo] 45.11 9.45\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Vabbuo io dico si, ma mica pozz rispondere semp? Nun sapess '
#   'proprio dove iniziare in questo caso.',
#   '[regione] Campania  [geo] 40.83 14.33\n'],
#  ['1',
#   'geolingit',
#   '[USER] Bon dai... Te gaverà la fila fin fora del porton',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.77 13.51\n'],
#  ['1',
#   'geolingit',
#   '[USER] anvedi questo che cazzo ha fatto. è ito in blocco come na caldaia',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] Sopratutto di Mario rui.......ma overament facit ????????',
#   '[regione] Campania  [geo] 40.91 14.15\n'],
#  ['1',
#   'geolingit',
#   '[USER] Io sono un neofita (farmaci costipanti), ma sti cázz’i morroidi '
#   'fannu mali. #Pruni a volontà.',
#   '[regione] Calabria  [geo] 39.35 16.19\n'],
#  ['1',
#   'geolingit',
#   '[USER] U capii...ma na tri grammi ti ciniri chi minchia voi ca ti nesci '
#   'l’arbustu...? Ti nesci n’bonsai e cia diri grazii...',
#   '[regione] Sicilia  [geo] 37.46 15.03\n'],
#  ['1',
#   'geolingit',
#   '[USER] Sa fotza si medit cun sa fotza e cun su cheveddu, su faeddu segund a '
#   "mie no b'intrat nudda, ma atzetto comente la pensas tue su matessi, 💪💪💪 "
#   'grande giua',
#   '[regione] Sardegna  [geo] 40.58 8.56\n'],
#  ['1',
#   'geolingit',
#   'Sarà che mi sto avvicinando ai 50 ma come dice sempre la mia amica [USER] '
#   '...Sole, mare e 30 gradi tutto l’anno (taaaac)! 😂😂 brrrrr che frech ❄️❄️! @ '
#   '[LOCATION] [URL]',
#   '[regione] Lombardia  [geo] 45.64 9.14\n'],
#  ['1',
#   'geolingit',
#   'Compare, e mù...gna faceme❓😂😂😂😂😂😂😂 [USER] [URL]',
#   '[regione] Abruzzo  [geo] 42.33 14.37\n'],
#  ['1',
#   'geolingit',
#   '[USER] Boja, perdavvero dé!',
#   '[regione] Toscana  [geo] 43.5 10.15\n'],
#  ['1',
#   'geolingit',
#   "[USER] C'è ne sono già anche troppi di pappa a uffo, dai mettiamone altri "
#   'che ne sentiamo la mancanza, ma va va va',
#   '[regione] Toscana  [geo] 44.09 10.51\n'],
#  ['1',
#   'geolingit',
#   "Pa pizza mi rissiru e 9 e 15 e m'ha purtaru e 9. Chié stu fattu?",
#   '[regione] Sicilia  [geo] 36.75 14.93\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] E quann o vir stu juorn?',
#   '[regione] Lazio  [geo] 41.23 13.53\n'],
#  ['1',
#   'geolingit',
#   '[USER] No stej a chied picchè lu termin “abbì” è abruzzes. Ciasant oh',
#   '[regione] Abruzzo  [geo] 42.51 13.97\n'],
#  ['1',
#   'geolingit',
#   'Greta amore sei bravissima però m stai facenn scennr tutt cos ndimen ca o '
#   'cor ra chies è chiu allegr #Sanremo2021',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] Si tien ciort t faj e sord seri.... Ma kmq nel mio discorso Cie Nun '
#   'esiste che devi sputtanare la mia foto ma aro sta scritt',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ma secondo lui noi poracci come se dovemo mbriacà?',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   'Aleee. Finalmente ze finioooo.😍👌👍 BUON PRANZO A TUTTI FIOI. [URL]',
#   '[regione] Veneto  [geo] 45.8 11.56\n'],
#  ['1',
#   'geolingit',
#   '[USER] Allira pe falla bene dovevi da dire...oggi spigne na cifra 🤣🤣',
#   '[regione] Lazio  [geo] 41.88 12.22\n'],
#  ['1',
#   'geolingit',
#   '[USER] D’Alema, Bersani, Veltroni, Fassino, Rosy Bindi, Zingaretti, '
#   'Cuperlo, Occhetto, tutto il gota del Pci Pds, letteralmente, come si dice a '
#   'Foligno: “c’ho magnato li fascioli inzieme!”',
#   '[regione] Umbria  [geo] 42.98 12.78\n'],
#  ['1',
#   'geolingit',
#   '[USER] Io li trovo alternati a “ma quanto è ganza AOC” e roba(ccia) simile.',
#   '[regione] Toscana  [geo] 43.78 11.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] Iu adduoppu a cena nun ni vivu café sinnó nun ruommu',
#   '[regione] Sicilia  [geo] 36.75 14.93\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] A Piè, non c'è bisogno che venga detto 😅 Damme retta!! E poi "
#   'se capisce guardando il tuo faccino, non é proprio da comico... Io na mezza '
#   'idea me la so fatta 🤭',
#   '[regione] Lazio  [geo] 41.54 13.49\n'],
#  ['1',
#   'geolingit',
#   "[USER] Dai, famoie guera... Orfi' , me sa' che passate cattive "
#   "frequentazioni t'hanno fatto male e mo' le spari più grosse e incazzose del "
#   'tuo vecchio amico.',
#   '[regione] Lazio  [geo] 41.65 12.5\n'],
#  ['1',
#   'geolingit',
#   '[USER] Na maniata di luoghi comuni.. Siccome si frica iddru ca è di Capurso '
#   '(BA)',
#   '[regione] Calabria  [geo] 39.27 16.27\n'],
#  ['1',
#   'geolingit',
#   '[USER] Io boja.. Si parte bene. Via vien qua a piglià il caldo del camino '
#   '.. ma che oki e oki..',
#   '[regione] Toscana  [geo] 43.84 10.57\n'],
#  ['1',
#   'geolingit',
#   "[USER] Ma c'è una commemorazione in corso , l'è muort qualchidun?? 🤣",
#   '[regione] Friuli-Venezia Giulia  [geo] 45.67 13.78\n'],
#  ['1',
#   'geolingit',
#   "[USER] Al g'ho di gacc po a me, pota alura! 🐱🐈",
#   '[regione] Lombardia  [geo] 45.7 9.6\n'],
#  ['1',
#   'geolingit',
#   '[USER] Mi fici a suoggira? Pronta sono! 🤣',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Ultimo giorno di”Festivalletteratura”p.zza Sordello panino '
#   'con cotechino caldo+Lambrusco 😜lassa perdar le nutrie👋👋💋💋',
#   '[regione] Lombardia  [geo] 45.14 10.81\n'],
#  ['1',
#   'geolingit',
#   "Chist'ann o miracol nun le fatt San Gennà e nuj a fest nun ta facimm. "
#   'Napoli ha stutat tutte e luci. Napoli ha fermat tutt e cor. Simm addiventat '
#   "una voce. Chist'ann San Gennà m'rispiac tenimm tutt quant na cos over a "
#   "pensà. Io, chist'ann, l'auguri nun te veng a fa. 💔",
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   "E be' si io so'un gran poeta ! Che El bon DIO a' sgrezato co' là creta "
#   "perciò famme onore ..se na' parola mia ta' corpito er core ! Sai a volte la "
#   "poesia è capace de Donà ar monno un po'de ☮️ pace !",
#   '[regione] Lazio  [geo] 41.95 12.93\n'],
#  ['1',
#   'geolingit',
#   'Madò che fadiga ster al mond!!!! [URL]',
#   '[regione] Emilia Romagna  [geo] 44.78 10.69\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ehi Marriaa...se avrò occasione di vedere un tuo sorriso strapperò '
#   'na bona boza de ros.',
#   '[regione] Trentino-Alto Adige  [geo] 45.85 11.06\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ch’è stat? Se ‘po sapè ch’è è stat?',
#   '[regione] Lazio  [geo] 41.36 13.31\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Biagio abbiamo scoperto il pesce frollato ieri e oggi il '
#   'pesce pigliat ca bott... 😂 😂',
#   '[regione] Campania  [geo] 40.97 14.2\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] le famosi nostre origini. Dovemo sempre arzà na polemica',
#   '[regione] Lazio  [geo] 41.88 12.22\n'],
#  ['1',
#   'geolingit',
#   "[USER] Butt' d' v'len allor Cà ston' Trad. A loro che ci sono espellessero "
#   'il veleno',
#   '[regione] Puglia  [geo] 40.56 16.96\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] “C’avemo i moscioli e ce piace el vì” (Classico adagio '
#   'anconetano)',
#   '[regione] Marche  [geo] 43.57 13.49\n'],
#  ['1',
#   'geolingit',
#   '#MasterChefIt Ma daiiii la ragazza cinese sposata con un barese 🤗🤗🤗 e pur l '
#   'cavatidd ha fatt!',
#   '[regione] Puglia  [geo] 41.09 16.87\n'],
#  ['1',
#   'geolingit',
#   '[USER] so ito a fa du vongole 🤣🤣🤣🤣',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] Buona dìe a tui puru ☺️',
#   '[regione] Sardegna  [geo] 39.29 8.54\n'],
#  ['1',
#   'geolingit',
#   "[USER] Scì va vène ma doeamo vince' co' le francesi. Invece ce semo fatti "
#   'magnà el "naso" dalle mosche... 😢',
#   '[regione] Marche  [geo] 43.32 12.91\n'],
#  ['1',
#   'geolingit',
#   "Fin a ieri era 'n casino trová uno positivo, ora siete tutti positivi? Ma "
#   "ve l'andate a pigliá ner culo...😩",
#   '[regione] Toscana  [geo] 43.66 10.36\n'],
#  ['1',
#   'geolingit',
#   'In romagna. Ma va a fe e capeloni.tan capesc gnint.antico detto rom [URL]',
#   '[regione] Emilia Romagna  [geo] 44.22 12.06\n'],
#  ['1',
#   'geolingit',
#   'Si lamentano che stanno solə, però se sentono talmente sto cazzo che quellə '
#   'che ci provano so poraccə pe loro ....se non scennete da sti piedistalli '
#   "v'attaccate riccamente ar cazzo #perdire",
#   '[regione] Lazio  [geo] 41.49 12.59\n'],
#  ['1',
#   'geolingit',
#   "intellettuale e trovaghiannu cu cazzu ca minchia e cu culu, a testa l'hannu "
#   "i tedeschi e u cori l'hannu oltretutto le persone speciali molti dei quali "
#   'considerati lupi, non comu a vurpi di dhu fetusu i diu (per il vecchio '
#   'testamento)',
#   '[regione] Sicilia  [geo] 38.15 14.87\n'],
#  ['1',
#   'geolingit',
#   '[USER] Fa un ben, date co na seppa in testa altro che tampon ai putei 😡😡😡 a '
#   'scuola, ci entrano comunque per legge. Vergognoso!',
#   '[regione] Veneto  [geo] 45.4 12.38\n'],
#  ['1',
#   'geolingit',
#   'Mamm ro carmn ma perché nun se sta zitt [URL]',
#   '[regione] Campania  [geo] 40.77 14.26\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Nenti sacciu',
#   '[regione] Sicilia  [geo] 37.9 14.37\n'],
#  ['1',
#   'geolingit',
#   'Immagino si riferisca a Leu o al PD. Ah mi scusi dimenticavo la '
#   'robotizzazione di massa. Curatevi e se proprio non ce ka fate a '
#   "trattenervi: fatevi la terza dose. Ma cos ' e pazz. [URL]",
#   '[regione] Campania  [geo] 40.09 15.58\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ghe cantemo in coro se i g’ha tute le fasine al cuerto 😂',
#   '[regione] Veneto  [geo] 45.44 11.0\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Robe Nun c’avemo na lira senza cessioni Avoja a dì Avoja a fà '
#   '🤐',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Mah, forse perché gh’u dì che capissi no perché la parlà (cul '
#   'cû) dii robb italian se la paga gnanca un cicc de tass, vist che la sta in '
#   'Svisera 🤷🏻\u200d♂️',
#   '[regione] Lombardia  [geo] 45.46 9.15\n'],
#  ['1',
#   'geolingit',
#   'Ma comm è brav stu uaglion 💙 [URL]',
#   '[regione] Campania  [geo] 40.77 14.26\n'],
#  ['1',
#   'geolingit',
#   '[USER] A mort che cammin. Quann si brutt,peggio e na cambiala in protesta. '
#   "Ma chi t'ha mis indo o governo?",
#   '[regione] Campania  [geo] 40.81 14.34\n'],
#  ['1',
#   'geolingit',
#   'e brau piciu continua a berti litri di coca cola allora👌 Squid News [URL]',
#   '[regione] Piemonte  [geo] 45.01 7.55\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Annamo bene ma do’ annamo ?',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] Ie un ci vo' nemmen morta.",
#   '[regione] Toscana  [geo] 43.78 11.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] Tutto ciò mi ricorda quando da cinno tirai un gavettone pieno di '
#   'lambrusco (preso dalla cantina di mio padre) ad un altro cinno stronso che '
#   'mi aveva segnato la bici.',
#   '[regione] Emilia Romagna  [geo] 44.48 11.33\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Cazzo se gli donano quattro Tornado vengono a bombardarci, '
#   'che je pija ncorpo',
#   '[regione] Umbria  [geo] 42.42 12.51\n'],
#  ['1',
#   'geolingit',
#   '[USER] Si vabbè...cu stu cazz i Adani al commento tecnico ultimamente nun '
#   'azzccamm na scop',
#   '[regione] Campania  [geo] 40.79 14.43\n'],
#  ['1',
#   'geolingit',
#   '[USER] Arraccia de sono bellu de iscurtare, giai funti acconcioso 🤦\u200d♀️',
#   '[regione] Sardegna  [geo] 40.54 9.7\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ghe sboro go visto de chee robe da stramusoni',
#   '[regione] Veneto  [geo] 45.39 11.89\n'],
#  ['1',
#   'geolingit',
#   '[USER] Mazza oh, sei na pischella! Auguri!',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ma nanca per i ball... 😜',
#   '[regione] Lombardia  [geo] 45.46 9.15\n'],
#  ['1',
#   'geolingit',
#   "[USER] Piuttosto domani vir e fa l'omm si t riesce !",
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] non te invidio pe gnente',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] [USER] E che n'aggia fa? Mò me metto a fa' o portiere....",
#   '[regione] Campania  [geo] 40.91 14.78\n'],
#  ['1',
#   'geolingit',
#   "v'avemo sgamato 2 ore fa. [URL]",
#   '[regione] Lazio  [geo] 41.98 12.69\n'],
#  ['1',
#   'geolingit',
#   '[USER] Lo sapevo. Solo lee bollette da pagare dividono qui. Per il resto '
#   'Icche glie mio è anche tuo Icche glie tuo ......... È solo tuo. 😘',
#   '[regione] Toscana  [geo] 43.88 11.09\n'],
#  ['1',
#   'geolingit',
#   "Notte de chelu es custa d'ogni sinu de allegria si sentit bundare, ca in sa "
#   'grutta es nadu su Bambinu dai s\'inferru pro nos liberare. "Es nadu, es '
#   "nadu, es nadu su Bambinu. Enide, enide tottus a l'ammirare, enide a "
#   "l'adorare, enide a l'adorare, a l'amare #leredita #BuonNatale",
#   '[regione] Sardegna  [geo] 39.94 8.94\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] [USER] [USER] Oooohhhh so 24 ore che dici strunzat. Ma '
#   'non tieni niente da fare? Vatt a fa nu bagn',
#   '[regione] Campania  [geo] 41.08 14.35\n'],
#  ['1',
#   'geolingit',
#   'Luca S schiatt ro cavr lievt sta giacc e mettiti nu bellu bermuda che '
#   'nfradit ahhahahahahah #LDA [USER] [URL]',
#   '[regione] Campania  [geo] 40.93 14.48\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] cor cazzo stessa cosa avoja a fa kilometri sur '
#   'raccordo',
#   '[regione] Lazio  [geo] 41.88 12.22\n'],
#  ['1',
#   'geolingit',
#   'Resuscitiamo twitterino, và No Whatsapp, Facebook or Instagram? Nessun '
#   'problema! A li tiampi mia, come dicono al mio paese, a sta ura nci volia '
#   'du’ cumpari e nu bellu fhuacu, atru ca Fedez e la Ferragni, ca na vota '
#   'tutte ste cose no l’aviamu 😜 #FacebookInstagramwhatsappdown',
#   '[regione] Calabria  [geo] 38.81 16.37\n'],
#  ['1',
#   'geolingit',
#   '[USER] Sciotto ni fici cadiri malati, e noi a lui 😂😂😂😂',
#   '[regione] Sicilia  [geo] 38.11 14.99\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ma soprattutto perché comunque tu proponi un contratto con un '
#   'allungamento di massimo 2 settimane e di bonu e bonu lanci questa bomba? Ma '
#   'proprio umanità zero.',
#   '[regione] Sicilia  [geo] 37.46 15.03\n'],
#  ['1',
#   'geolingit',
#   '[USER] Anche perché se no te pijo a mozzichi 🤣🤣🤣',
#   '[regione] Lazio  [geo] 41.96 12.76\n'],
#  ['1',
#   'geolingit',
#   '[USER] A capu è nu bellu i cipulla',
#   '[regione] Calabria  [geo] 39.27 16.27\n'],
#  ['1',
#   'geolingit',
#   '#staseraitalia ARIDANGA.. I BOMBA UNNÈ FIORENTINO GLIÈ DI RIGNANO OVVIA !!',
#   '[regione] Toscana  [geo] 43.78 11.24\n'],
#  ['1',
#   'geolingit',
#   'Pat e Maria vi prego stravolgete il gioco perché ho le palle piene. '
#   'Enormemente piene. Al3x B3lli cesso deve sparire da sta casa. Arret u zit '
#   'della Cipriani. Ma veramente facciamo? Stiamo guardando la stessa identica '
#   'dinamica da mille anni. NON SE NE PUÒ PIÙ #gfvip',
#   '[regione] Puglia  [geo] 41.09 16.87\n'],
#  ['1',
#   'geolingit',
#   'u t vo piar da vucca/magar a madonna [URL]',
#   '[regione] Calabria  [geo] 39.1 17.1\n'],
#  ['1',
#   'geolingit',
#   'Comunque e facess perder sol pecchè usciti dall’europa m stann ncopp o cazz',
#   '[regione] Campania  [geo] 40.84 14.1\n'],
#  ['1',
#   'geolingit',
#   '[USER] magari je se apre na voraggine',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] E cu Sinni futti Ca' diu pidduna a tutti",
# ...
#  ['1',
#   'geolingit',
#   '[USER] Mia mamma mi diceva, al quasi ghe manca tut ..... a conti fatti sono '
#   'più i morti col vax 🤔🤔🤔... per il vax',
#   '[regione] Trentino-Alto Adige  [geo] 46.06 11.1\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ahahahah bonu fici si meritava tutti i vastunati',
#   '[regione] Sicilia  [geo] 37.89 15.3\n'],
#  ['1',
#   'geolingit',
#   "[USER] Se poi non c'è bisogno, mejo così, s'annamo a fa'tutti na bella "
#   'pennica',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] Mur da piciu. I piemontesi capiscono.....',
#   '[regione] Piemonte  [geo] 44.95 8.41\n'],
#  ['1',
#   'geolingit',
#   '#exrosmello #mellos Della serie : MA DI FIURI MAI NCI SECCUNU😅 [URL]',
#   '[regione] Puglia  [geo] 40.59 17.88\n'],
#  ['1',
#   'geolingit',
#   '[USER] Mancu mali, seu andende de Casteddu a Lollove e in Galtellì . Bona '
#   'die',
#   '[regione] Sardegna  [geo] 39.39 9.13\n'],
#  ['1',
#   'geolingit',
#   '[USER] ma che cazzo dice sto trimone,non capite un cazzo di pesce.',
#   '[regione] Puglia  [geo] 41.23 16.39\n'],
#  ['1',
#   'geolingit',
#   "[USER] Solo questo mancava meloni la piu' gradita in italia! Pensa la piu' "
#   "sgradita chi.puo' essere ,suma a post poveri noi",
#   '[regione] Piemonte  [geo] 45.06 7.52\n'],
#  ['1',
#   'geolingit',
#   'Von der Leyen: "Sanzioni avranno un costo anche per noi, gli europei '
#   'capiranno" RINT A CHELLA GRANDA ZOMPAPERETA E MAMMT A TE E CHILLU CURNUT E '
#   'BIDEN',
#   '[regione] Campania  [geo] 40.63 14.48\n'],
#  ['1',
#   'geolingit',
#   'Comunque quello che je compra tutta Malibù sta ingranato fracico...',
#   '[regione] Lazio  [geo] 41.88 12.22\n'],
#  ['1',
#   'geolingit',
#   'DER MAIALE NSE BUTTA GNIENTE DAA MAIALA SE TIENE SOLO ER NUMERO',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "[USER] Buon Natale omino. Un piglià l'umido",
#   '[regione] Toscana  [geo] 43.84 10.57\n'],
#  ['1',
#   'geolingit',
#   '[USER] Madonna cussu una furia!',
#   '[regione] Puglia  [geo] 41.09 16.87\n'],
#  ['1',
#   'geolingit',
#   '[USER] Allora io le bugie degli uomini non le accetto più capito? Non ti '
#   'puoi prendere e lasciare na vot o juorn o sce! Nun c fai capi nient e che '
#   'cazz 😡🤬',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] Omm e panz, omm è sustanz. 🤣🤣🤣🤣',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] di [USER] al #governo sarebbe ridicola. #diononvoglia Ma come '
#   'dimostrato dalla drammatica questione del #superbonus questo #Governo di '
#   'cazzari [USER] [USER] [USER] [USER] [USER] mancu cugghiunia vah. '
#   '#superbonus110 #truffa?',
#   '[regione] Sicilia  [geo] 37.84 15.26\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ho magna’ crauti e luganega ancoi, vale istess? 😅',
#   '[regione] Trentino-Alto Adige  [geo] 45.88 10.81\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] A xe più sveja de noialtri do insieme',
#   '[regione] Veneto  [geo] 45.4 12.38\n'],
#  ['1',
#   'geolingit',
#   '[USER] Si sentia na spertazzuna.. sa ciota fricata',
#   '[regione] Calabria  [geo] 39.27 16.27\n'],
#  ['1',
#   'geolingit',
#   "A me la stiacciata coll'uva la mi piace con tanta uva; e co' semi. Sennò "
#   "unn'è stiacciata. [URL]",
#   '[regione] Toscana  [geo] 43.78 11.24\n'],
#  ['1',
#   'geolingit',
#   'Simpatico il mio “amico” che oggi ha evitato in tutti i modi di salutarmi! '
#   'Vai pure tranquillo ‘ca sesi prusu impestau tui de tottusu cussusu chi indi '
#   'funti lompiusu de sa Lombardia; o culu tontu!',
#   '[regione] Sardegna  [geo] 39.88 9.5\n'],
#  ['1',
#   'geolingit',
#   '[USER] Na vita de stenti. Tocca facce pace sin da regazzini.',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] E mo’ chi jo dice ar berlusca che avemo perso per tutte le ca..ate '
#   'c’avemo detto?!?',
#   '[regione] Lazio  [geo] 41.88 12.22\n'],
#  ['1',
#   'geolingit',
#   '[USER] Sugnu vasciu, sugnu bruttu almenu chiddu (u cori) l’aia sapiri '
#   'usari...',
#   '[regione] Sicilia  [geo] 37.46 15.03\n'],
#  ['1',
#   'geolingit',
#   'Grucciate agli zoppi. #Fiorentina [URL]',
#   '[regione] Toscana  [geo] 43.78 11.24\n'],
#  ['1',
#   'geolingit',
#   'Mi vojo ndar bere co el gegno che gà programmà sto cantiere dove no ghe '
#   'lavora MAI nessun [URL]',
#   '[regione] Veneto  [geo] 45.5 11.47\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Per non dimenticare, Maggiu ancora friddu aggiu, nel senso '
#   "che la vera primavera puo' non arrivare fino a maggio.",
#   '[regione] Puglia  [geo] 40.59 17.88\n'],
#  ['1',
#   'geolingit',
#   "Se è bieru ca u munnu gira... ri cca'avi a passari! E molto buon "
#   'pomeriggio! [URL]',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   'Mamm ro carmn che sofferenza clamorosa, però almeno l’abbiamo portata a '
#   'casa dai #BeneventoNapoli',
#   '[regione] Campania  [geo] 40.77 14.26\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Si però [USER] so boni tutti a pubblicare le cose mainstream '
#   'tira fuori sta roba che io in una settimana ho visto due cose incredibili '
#   'che non avevo mai visto gnamo... ti si segue per quello eh dai dai',
#   '[regione] Toscana  [geo] 42.9 10.83\n'],
#  ['1',
#   'geolingit',
#   "[USER] Io di Allegri ma l'Andrea al me piasss ❤",
#   '[regione] Lombardia  [geo] 45.61 9.5\n'],
#  ['1',
#   'geolingit',
#   '[USER] 🤔 ma tuo cognato l’ha saputo del tuo compleanno o l’ha fa’ nanca '
#   'finta?',
#   '[regione] Lombardia  [geo] 45.46 9.15\n'],
#  ['1',
#   'geolingit',
#   'Famo sto stadio 😂 mortacci vostri mortacci',
#   '[regione] Lazio  [geo] 41.88 12.22\n'],
#  ['1',
#   'geolingit',
#   '[USER] A mia ma ponnu minari a du mani #ecco',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   '[USER] Ho tradotto un detto romagnolo "L\'era acse\' furb que ades l\'è\'in '
#   'manicomi" "Era così furbo che adesso è in manicomio" 😅🤣😂',
#   '[regione] Emilia Romagna  [geo] 44.29 11.89\n'],
#  ['1',
#   'geolingit',
#   '[USER] Vedaremo cossa che sucede doman!',
#   '[regione] Veneto  [geo] 45.85 12.23\n'],
#  ['1',
#   'geolingit',
#   'Da nerd dichiarata non avevo mai visto il più brutto film basato su fumetto '
#   'mai realizzato secondo vagonate di recensioni. Ora ho recuperato. È anche '
#   'peggio di quel che pensavo. Occhi di gatto era più credibile. Halle Berry '
#   'stragnocca ovviamente (almanco queo!!!) #Catwoman',
#   '[regione] Veneto  [geo] 45.68 11.48\n'],
#  ['1',
#   'geolingit',
#   '[USER] I se e i ma i spaca i marun...',
#   '[regione] Emilia Romagna  [geo] 44.8 11.67\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Ridi ridi. Mi no posso uscir, nessun ne fa la spesa e da noi '
#   'non esisti i vari corrieri che porta de magnar. Adesso vedemo se il '
#   'supermercato consegna a domicilio. 😭',
#   '[regione] Friuli-Venezia Giulia  [geo] 45.77 13.51\n'],
#  ['1',
#   'geolingit',
#   "'Nse po' fa 'sta vita 'pe 'na vita",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Bon anno anca a ti e a tuti i to parenti 🥂🍾🐞',
#   '[regione] Veneto  [geo] 45.91 12.44\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] E se nun te ne frega n cazzo, come mai continui a risponne? '
#   "Chiedo pe n'amico milanese eh...",
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] Lu colore se n’tona co quello de li capelli 🤣🤣🤣',
#   '[regione] Umbria  [geo] 42.42 12.51\n'],
#  ['1',
#   'geolingit',
#   "[USER] Risponde a chi ti fa un discorso 'osí, vordí abbassassi a 'r su "
#   'livello...😤',
#   '[regione] Toscana  [geo] 43.66 10.36\n'],
#  ['1',
#   'geolingit',
#   "[USER] Quando si dice uno schiaffo alla [URL] e' pur vero che u spazio "
#   'uncridi o diunu',
#   '[regione] Sicilia  [geo] 37.31 13.57\n'],
#  ['1',
#   'geolingit',
#   '[USER] Fa chell ca vuo amo! Tant si semp bell',
#   '[regione] Campania  [geo] 40.98 14.16\n'],
#  ['1',
#   'geolingit',
#   '[USER] ❤️ Soprattutto, il pancotto, a celebrare degnamente una mattinata '
#   'perfetta. Fatto con la stagnola del dado, perché “il dadu l’è tropp grass” '
#   '(secondo la ricetta di mio nonno).',
#   '[regione] Lombardia  [geo] 45.46 9.15\n'],
#  ['1',
#   'geolingit',
#   'Ogni volta il partito “è colpa dell’arbitro” e quello “semo scarsi nessun '
#   'alibi” Nun se piamo per culo: ieri avemo fatto poco per portarla a casa, ma '
#   'perché questo deve autorizzare a trattamenti come quelli su #Zaniolo o '
#   'privarti di #Abraham vs l’Inter, stile #Pellegrini-derby?',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   "[USER] Con du topi 'osí ci faccio lo zabaione...😩",
#   '[regione] Toscana  [geo] 43.64 10.63\n'],
#  ['1',
#   'geolingit',
#   "[USER] Te ghet piou vint'ann... Gna trenta.. Gna Quaranta😂",
#   '[regione] Lombardia  [geo] 45.91 9.34\n'],
#  ['1',
#   'geolingit',
#   'ICCASSI VUCI 🤦\u200d♀️🤦\u200d♀️🤦\u200d♀️ [URL]',
#   '[regione] Sicilia  [geo] 38.13 13.34\n'],
#  ['1',
#   'geolingit',
#   "04.06.2021 In zir p'r Cod'na...260 mt s.l.m. Codena è una frazione a monte "
#   'di Carrara Ms [URL]',
#   '[regione] Toscana  [geo] 44.07 10.09\n'],
#  ['1',
#   'geolingit',
#   "Dalle parti mie la sera è un continuo di botti e fuochi d'artificio. Vorrei "
#   'pacatamente chiedere a questi signori: "MA CHE SFACCIMM TENIT A SPARA\' '
#   "TUTTE 'E SERE?? MA NUN TENIT MEGLIO 'A FFA'?? MOCC A CHI V'È "
#   'STRAVIV\'!!"',
#   '[regione] Campania  [geo] 40.92 14.51\n'],
#  ['1',
#   'geolingit',
#   "Ma c'hai du' spicci pe' na bira? #bangla 😂",
#   '[regione] Umbria  [geo] 43.04 12.45\n'],
#  ['1',
#   'geolingit',
#   '[USER] Bettini ha scritto un articolo raccapricciante, tutto un “so stati '
#   'l’artri” “nun è córpa nostra” la chiusura con Conte punto di partenza è '
#   'allucinante. Che finaccia',
#   '[regione] Umbria  [geo] 42.4 12.54\n'],
#  ['1',
#   'geolingit',
#   'Diamoci un taglio col 2020, intanto stasera #propagandalivetombola '
#   '#propagandalive poi da domani ci vuole un cappellino perché l’è diaccio co '
#   'i capino nudo 😂😂 @ [LOCATION] [URL]',
#   '[regione] Toscana  [geo] 43.78 11.24\n'],
#  ['1',
#   'geolingit',
#   'E statt nu poc zitt. Me pari nu jettatore ! [URL]',
#   '[regione] Campania  [geo] 41.4 13.97\n'],
#  ['1',
#   'geolingit',
#   '[USER] La lui sona è più pesante, mortale, è un masagno immangiabile, '
#   'questa è morbida e piacevole. Impaluga 👍',
#   '[regione] Emilia Romagna  [geo] 44.48 11.33\n'],
#  ['1',
#   'geolingit',
#   'Mado raga stamo fori cor botto. ❤️ [URL]',
#   '[regione] Lazio  [geo] 41.89 12.54\n'],
#  ['1',
#   'geolingit',
#   '[USER] Pigemmu quellu che vegnie 🤣🤣🤣🤣',
#   '[regione] Liguria  [geo] 44.44 8.88\n'],
#  ['1',
#   'geolingit',
#   '[USER] Chi camurria Saretta, come faremo senza di te. Ti rimetterai presto. '
#   'Lo dice il tuo sorriso. Chi alla vita sorride la vita sorride a lui, scusa '
#   'a lei. A lui o a lei, mizzica chi camurria.',
#   '[regione] Sicilia  [geo] 37.22 14.86\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Paole’, tu chiagn i muort e futt i vivi! La sai lunga tu ! '
#   '[USER] concordi ?',
#   '[regione] Lazio  [geo] 41.46 13.94\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Noooo che poi famo na strage de pupi 😂😂😂😂😂',
#   '[regione] Lazio  [geo] 42.18 12.29\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] Un pochino? Al g'ha na panza da mat. Poi consiglierei anche "
#   "un pantalone un po' più largo, non è necessario esibire i propri cm",
#   '[regione] Emilia Romagna  [geo] 44.8 11.67\n'],
#  ['1',
#   'geolingit',
#   '[USER] Sannu mis o’cappott sti zoccl',
#   '[regione] Campania  [geo] 40.95 14.52\n'],
#  ['1',
#   'geolingit',
#   'Caro #trump sei pure avanti con l’età , statt accort ! [URL]',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   "[USER] Gli allevatori non ci sono più perché son lavoracci, un c'è feste, "
#   "ti fai un culo 'osí, e il guadagno è minimo. Ma quando li facevano loro, la "
#   'carne era bona, anzi strabona...',
#   '[regione] Toscana  [geo] 43.66 10.36\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] 😂😂😂 Hai ragione... E chi parl chiu.. 😂😂',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   'Scusate.. Ma Aiello sta cantando o sta iccannu vuci? #Sanremo2021',
#   '[regione] Sicilia  [geo] 38.07 13.49\n'],
#  ['1',
#   'geolingit',
#   "[USER] Boia, ci manca poo 'ascava..",
#   '[regione] Toscana  [geo] 43.64 10.63\n'],
#  ['1',
#   'geolingit',
#   'Te pare che piji #Mourinho e non je dai la squadra? Ecco.',
#   '[regione] Lazio  [geo] 41.65 12.76\n'],
#  ['1',
#   'geolingit',
#   "Fo' pe' divvelo...😷😷🩲😷😷🩲😷😷😷😷😷😷😷🩲😷 [URL]",
#   '[regione] Toscana  [geo] 43.73 11.15\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] [USER] Vojo di mejo de così se more',
#   '[regione] Lazio  [geo] 42.13 12.36\n'],
#  ['1',
#   'geolingit',
#   'Ora vu mi fate incazzare anche me e io sono per il #vaccino #mascherina ecc '
#   'e vado per i terzo e lo farò ma se per andare al #cinema #ristorante ecc ci '
#   'vuole anche il tampone andate Tutti in culo Vu potehe chiudere i bandone',
#   '[regione] Toscana  [geo] 43.78 11.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] Mi el vurevi no propi per quel mutif chi, ma uramai ghe l u',
#   '[regione] Lombardia  [geo] 45.53 9.28\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] Ma che maron, è chiu muort che viv chist',
#   '[regione] Campania  [geo] 40.85 14.24\n'],
#  ['1',
#   'geolingit',
#   '[USER] No esti di aicci. Sesi sballiendi',
#   '[regione] Sardegna  [geo] 39.22 9.09\n'],
#  ['1',
#   'geolingit',
#   "Su concime appo leadu, l'happo a impreare pro su patate e Matera cosas in "
#   'beranu [URL]',
#   '[regione] Sardegna  [geo] 40.58 8.56\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] mbareeeeee accattati l'Inter ca' è troppu bedda",
#   '[regione] Sicilia  [geo] 37.25 15.0\n'],
#  ['1',
#   'geolingit',
#   'Comunque nell azione scandalo del rigore non ha sbagliato Banti non ha '
#   'sbagliato Guida ha sbagliato Mancini che je doveva trincià le gambe subito. '
#   'Je doveva mandà la tibia nel nostro settore',
#   '[regione] Lazio  [geo] 41.88 12.22\n'],
#  ['1',
#   'geolingit',
#   '#napoligenoa Se è complotto.... uagliú chest è a fin ro mun Amma scumparí',
#   '[regione] Campania  [geo] 40.9 14.35\n'],
#  ['1',
#   'geolingit',
#   '#gingerboy : cavei rossi, sfesa e lentiggini! @ [LOCATION] [URL]',
#   '[regione] Friuli-Venezia Giulia  [geo] 46.0 12.6\n'],
#  ['1',
#   'geolingit',
#   "#Osimhen afammocc...era ora...e che cazzo... Grande Uaglio'",
#   '[regione] Campania  [geo] 40.79 14.43\n'],
#  ['1',
#   'geolingit',
#   'I miei clienti nun m supporto chiu comm s’Assa fa 🤣🤣🤣🤣 #LDA [URL]',
#   '[regione] Campania  [geo] 40.91 14.38\n'],
#  ['1',
#   'geolingit',
#   'Ah no, non sta a piagne, sta proprio a urla de tigna',
#   '[regione] Marche  [geo] 43.46 13.56\n'],
#  ['1',
#   'geolingit',
#   "[USER] U diau l'è in ce u se ghe farti u niu'",
#   '[regione] Liguria  [geo] 44.32 9.31\n'],
#  ['1',
#   'geolingit',
#   '[USER] Dalle mie parti si dice" u g\'ha a faccia come a Rebatüa da balla',
#   '[regione] Liguria  [geo] 43.86 7.93\n'],
#  ['1',
#   'geolingit',
#   "[USER] [USER] Se n'è sciutu alle cozze,metafora pugliese,Ve la traduco:il "
#   "suo cervello è fuggito. E poi abbiamo quel gran volpone di D'Alema "
#   ",lasciamolo veleggiare, è un po' che è alla deriva.che facciamo?",
#   '[regione] Puglia  [geo] 40.32 17.55\n'],
#  ['1',
#   'geolingit',
#   "I PARADOSSO DI ROSARECCIA o bimbi, ancora un gli si spiega, ma un c'è "
#   'storia eh, le bruschettine sarciccia e stracco di Rosareccia e so speciali. '
#   'Un si sa icche ci mette e icche ci rimestagne, ma glie so speciali. Gliè la '
#   'vita, un ci si pole fa nulla oh',
#   '[regione] Toscana  [geo] 43.55 10.88\n'],
#  ['1',
#   'geolingit',
#   'Se allenass a juve o vincess pur io o scudett Nun c’è vó tant🤣 tenessem nui '
#   'lukaku...ma oshimen sarà decisivo [URL]',
#   '[regione] Campania  [geo] 40.68 14.53\n'],
#  ['1',
#   'geolingit',
#   '[USER] Grandi passi avanti nel trasporto pubblico regionale eh, assessore. '
#   'Per fortuna c’è il covid. Ma quando xe finio el virus no to ga più scuse: '
#   'cambia lavoro.',
#   '[regione] Veneto  [geo] 45.6 12.22\n'],
#  ['1',
#   'geolingit',
#   '[USER] [USER] NO VABBÈ! Io mi sono appena svegliata e vi dirò che risveglio '
#   'bellissimo! Stogg tutt ai lov iu amo 😍',
#   '[regione] Puglia  [geo] 41.09 16.87\n'],
#  ['1',
#   'geolingit',
#   'Ma dove cazzo vogliamo andare. Dove me chiedo io Pe du spicci tradirebbero '
#   'pure er padre e la madre [URL]',
#   '[regione] Lazio  [geo] 41.89 12.54\n']]

# %%
def elaborate_generated_output(text):
    region, coordinates = [e.strip() for e in text.removeprefix("[regione]").strip().split('[geo]')]
    latitude, longitude = [float(e) for e in coordinates.split()]
    return region, (latitude, longitude)

# %%
# generate prompts based on task and text
pred_text = []
true_text = []

for input in tqdm(inputs):
    id = input[0]
    task = input[1]
    text = input[2]
    expected_output = input[3]

    instruction = task_to_prompt(task)
    prompt = generate_prompt_pred(instruction, text) #pay attention that the input is not too long (over the max length of your model)

    # tokenization
    tokenized_inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True).to(model.device)

    # inference
    model.eval()
    with torch.no_grad():
        gen_outputs = model.generate(
            **tokenized_inputs,
            return_dict_in_generate=True,
            output_scores=True,
            max_new_tokens=256, # how many token (wordpieces) to add to the input prompt. In ExtremITA answers are short
            do_sample=False # we do not need any sampling or beam seach. We just need the "best" solution, so the greedy search is fine: https://huggingface.co/blog/how-to-generate
        )

        # decoding and printing
        for i in range(len(gen_outputs[0])):
            output = tokenizer.decode(gen_outputs[0][i], skip_special_tokens=True)
            if "### Risposta:" in output:
                response = output.split("### Risposta:")[1].rstrip().lstrip()
            else:
                response = "UNK"

            # print(text)
            # print(f"\t {expected_output} \t {response}")
            # print(50*"*")
            
            pred_text.append(elaborate_generated_output(response))
            true_text.append(elaborate_generated_output(expected_output))
# Out:
# 100%|██████████| 818/818 [22:05<00:00,  1.62s/it]

# %% [markdown]
# ## Compute the metrics: F1 score for classification and avg km between coordinates

# %%
pred_region, pred_coord = tuple(zip(*pred_text))
true_region, true_coord = tuple(zip(*true_text))

avg_km = np.array([geodesic(p, t).km for p, t in zip(pred_coord, true_coord)]).mean()
score = f1_score(true_region, pred_region, average='macro')

print(f"Average distance in km: {avg_km}")
print(f"F1 score: {score}")
# Out:
# Average distance in km: 167.96833368812435
# F1 score: 0.3365633846445403

# %% [markdown]
# ![image.png](assets/extremita.PNG)
